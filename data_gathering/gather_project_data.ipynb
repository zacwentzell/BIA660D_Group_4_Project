# %%
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
import random
import numpy as np
import time
import requests
import bs4

# %%
raplistURL = [
    "https://www.billboard.com/charts/rap-song/2016-06-24",
    "https://www.billboard.com/charts/rap-song/2016-01-24",
    "https://www.billboard.com/charts/rap-song/2017-01-24",
    "https://www.billboard.com/charts/rap-song/2018-01-24"
]

rocklistURL = [
    "https://www.billboard.com/charts/rock-songs/2016-03-24",
    "https://www.billboard.com/charts/rock-songs/2017-03-24"
]

# %%
Song_Names = []
Artist_Names = []

# %%
def pageQuery(URL_List, numberPerPage):
    driver = webdriver.Chrome(executable_path='./chromedriver')
    time.sleep(3)
    for each in URL_List:
        n=1
        driver.get(each)
        time.sleep(5)
        print(each)
        while (n<=numberPerPage):
            try:
                element = (driver.find_element_by_xpath('//*[@id="main"]/div[2]/div/div/article['+str(n)+']'))
            except:
                element = (driver.find_element_by_xpath('//*[@id="main"]/div[3]/div/div/article['+str(n)+']'))
            Artist_Names.append(element.find_element_by_class_name("chart-row__artist").text)
            Song_Names.append(element.find_element_by_class_name("chart-row__song").text)
            n+=1
        print("done "+each)
#Song titles either are not being added to the list or they throw an error so I can't just use if statements.
#In TryExcept It doesn't seem like I can store variables.

# %%
pageQuery(raplistURL, 25)
# Out:
# https://www.billboard.com/charts/rap-song/2016-06-24
# done https://www.billboard.com/charts/rap-song/2016-06-24
# https://www.billboard.com/charts/rap-song/2016-01-24
# done https://www.billboard.com/charts/rap-song/2016-01-24
# https://www.billboard.com/charts/rap-song/2017-01-24
# done https://www.billboard.com/charts/rap-song/2017-01-24
# https://www.billboard.com/charts/rap-song/2018-01-24
# done https://www.billboard.com/charts/rap-song/2018-01-24

# %%
pageQuery(rocklistURL, 50)
# Out:
# https://www.billboard.com/charts/rock-songs/2016-03-24
# done https://www.billboard.com/charts/rock-songs/2016-03-24
# https://www.billboard.com/charts/rock-songs/2017-03-24
# done https://www.billboard.com/charts/rock-songs/2017-03-24

# %%
RockArtists = Artist_Names

# %%
RockSongs = Song_Names

# %%
RapArtists = Artist_Names

# %%
RapSongs = Song_Names

# %%
rapdata = {'Song': RapSongs, 'Artist': RapArtists, 'Lyrics': songLyrics}

# %%
rockdata = {'Song': RockSongs, 'Artist': RockArtists}

# %%
rapDf = pd.DataFrame(data = rapData)
rockDf = pd.DataFrame(data = rockData)
# Out:
#                                                Artist  \
# 0                                           Desiigner
# 1                                          Kent Jones
# 2                           DJ Khaled Featuring Drake
# 3                         Future Featuring The Weeknd
# 4   Fat Joe, Remy Ma & Jay Z Featuring French Mont...
# 5                                 G-Eazy x Bebe Rexha
# 6                             Drake Featuring Rihanna
# 7                  O.T. Genasis Featuring Young Dolph
# 8                                         Kevin Gates
# 9                          Drake Featuring The Throne
# 10                                             Future
# 11                                        Kevin Gates
# 12                                          MadeinTYO
# 13                                          Fetty Wap
# 14                 Pitbull Featuring Enrique Iglesias
# 15                                              Drake
# 16                                              Drake
# 17                                              Drake
# 18                             Drake Featuring Future
# 19                         Belly Featuring The Weeknd
# 20                                              Drake
# 4                          Disturbed                The Sound Of Silence
# 5                      X Ambassadors                           Renegades
# 6                  twenty one pilots                                Ride
# 7                  Empire Of The Sun                  Walking On A Dream
# 8                      The Lumineers                             Ophelia
# 9                      X Ambassadors                            Unsteady
# 10               Panic! At The Disco                          Victorious
# 11                        Miike Snow                        Genghis Khan
# 12                         Elle King                America's Sweetheart
# 13                          Coldplay                Hymn For The Weekend
# 14               Panic! At The Disco               Emperor's New Clothes
# 15                   The Strumbellas                             Spirits
# 16                          The 1975                           The Sound
# 17               Panic! At The Disco                 Death Of A Bachelor
# 18                             Kaleo                      Way Down We Go
# 19                             Foals                Mountain At My Gates
# 20                         Shinedown                    State Of My Head
# 21               Nothing But Thieves                         Trip Switch
# 22                 Cage The Elephant                         Mess Around
# 23                           BANNERS                        Start A Riot
# 24                            Hozier                 Arsonist's Lullabye
# 25                          The 1975                       Somebody Else
# 26                        The Struts                           Kiss This
# 27                              M83.                       Do It, Try It
# 28           Five Finger Death Punch                    Wash It All Away
# 29               Panic! At The Disco  Don't Threaten Me With A Good Time
# ..                               ...                                 ...
# 70                            MISSIO                      Middle Fingers
# 71                     Cold War Kids                    Love Is Mystical
# 72  Andrew McMahon In The Wilderness                         Fire Escape
# 73                        Papa Roach                                Help
# 74                 Portugal. The Man                       Feel It Still
# 75                             Kaleo                All The Pretty Girls
# 76                        John Mayer                 Love On The Weekend
# 77                            The xx                             On Hold
# 78                      Milky Chance                              Cocoon
# 79                 Cage The Elephant                      Cold Cold Cold
# 80                           Starset                             Monster
# 81         Catfish And The Bottlemen                                   7
# 82                        John Mayer            Still Feel Like Your Man
# 83                       Sylvan Esso                           Die Young
# 84                           Seether                        Let You Down
# 85                              LANY                          Good Girls
# 86                             Spoon                        Hot Thoughts
# 87                         Metallica                        Atlas, Rise!
# 88                         Beartooth                               Hated
# 89                          Bastille                               Blame
# 90                          DREAMERS                      Sweet Disaster
# 91                                LP                         Lost On You
# 92                           Incubus                      Nimble Bastard
# 93                 Breaking Benjamin                         Never Again
# 94                     Maggie Rogers                              Alaska
# 95                         Bob Moses                       Tearing Me Up
# 96                     Bishop Briggs                         Wild Horses
# 97                        Nickelback                    Feed The Machine
# 98                       Mondo Cozmo                               Shine
# 99                     NEEDTOBREATHE                           Hard Love
#
# [100 rows x 2 columns]

# %%
df.to_csv("rap.csv")

# %%
df1.to_csv("rock.csv")

# %%
songLyrics = []

# %%
def getSongLyrics(songName, songURL):
    driver = webdriver.Chrome(executable_path='/Users/Brennan/Desktop/Classes/BIA-660/RocknRapScraping/chromedriver')
    time.sleep(3)
    driver.get(songURL)
    time.sleep(5)
    lyricList = []
    
    element = driver.find_element_by_class_name('lyrics')
    element.find_element_by_tag_name('p')
    
    lyrics = element.find_elements_by_tag_name('a')
    for line in lyrics:
        lyricList.append(line.text)
    songLyrics.append(lyricList)

# %%
def songURL(artist, song):
    baseURL = "https://genius.com/"
    artist = artist.replace(" ","-")
    artist = artist.replace("&","and")
    artist = artist.replace("'","")
    artist = artist.replace("!","")
    artist = artist.replace(".","")
    artist = artist.replace(":", "")
    artist = artist.replace(",", "")
    artist = artist.replace("!", "")
    artist = artist.replace("-Featuring-Drake", "")
    artist = artist.replace("-Featuring-Kiiara", "")
    artist = artist.replace("-Featuring-The-Weeknd","")
    artist = artist.replace("Fat-Joe-Remy-Ma-and-Jay-Z-Featuring-French-Montana-and-Infared","Fat-joe-and-remy-ma")
    artist = artist.replace("G-Eazy-x-Bebe-Rexha","G-eazy")
    artist = artist.replace("-Featuring-Rihanna","")
    artist = artist.replace("BORNS","brns")
    artist = artist.replace("Lil-Wayne-Wiz-Khalifa-and-Imagine-Dragons-With-Logic-and-Ty-Dolla-$ign-Feat-X-Ambassadors","Atlantic-records")
    artist = artist.replace("-Featuring-Young-Dolph","")
    artist = artist.replace("-Featuring-The-Throne","")
    artist = artist.replace("-Featuring-Enrique-Iglesias","")
    artist = artist.replace("-Featuring-Future","")
    artist = artist.replace("-Featuring-E-40","")
    artist = artist.replace("-Featuring-Remy-Boyz","")
    artist = artist.replace("-Featuring-Nicki-Minaj","")
    artist = artist.replace("-Featuring-Big-Sean","")
    artist = artist.replace("-Featuring-Pharrell-Williams","")
    artist = artist.replace("-Featuring-Fetty-Wap-and-Rich-Homie-Quan","")
    artist = artist.replace("-and-DeJ-Loaf","")
    artist = artist.replace("-Featuring-TI-Young-Dolph-and-Ricco-Barrino","")
    artist = artist.replace("-Featuring-Lil-Uzi-Vert","")
    artist = artist.replace("-Featuring-Gucci-Mane","")
    artist = artist.replace("-x-Camila-Cabello","")
    artist = artist.replace("-and-Zayion-McCall","")
    artist = artist.replace("-Featuring-Future","")
    artist = artist.replace("-$tone-Featuring-J-Davi$-and-Spooks","-Stone")
    artist = artist.replace("-Featuring-Lil-Yachty","")
    artist = artist.replace("-Featuring-Future-and-Lil-Uzi-Vert","")
    artist = artist.replace("-Featuring-Nicki-Minaj-Chris-Brown-August-Alsina-Jeremih-Future-and-Rick-Ross","")
    artist = artist.replace("-Featuring-A$AP-Rocky","")
    artist = artist.replace("-Chris-Brown-August-Alsina-Jeremih-Future-and-Rick-Ross","")
    artist = artist.replace("-Featuring-21-Savage","")
    artist = artist.replace("-Featuring-Nicki-Minaj-Chris-Brown-August-Alsina-Jeremih-Future-and-Rick-Ross","")
    artist = artist.replace("-and-Lil-Uzi-Vert","")
    artist = artist.replace("-Featuring-Lil-Wayne","")
    artist = artist.replace("-and-Cardi-B","")
    artist = artist.replace("-and-2-Chainz","")
    artist = artist.replace("-Nicki-Minaj","")
    artist = artist.replace("-Featuring-XXXTENTACION","")
    artist = artist.replace("-Featuring-Migos","")
    artist = artist.replace("-Featuring-Zacari","")
    artist = artist.replace("-Featuring-Ed-Sheeran","")
    artist = artist.replace("-Featuring-Yo-Gotti-A-Boogie-Wit-da-Hoodie-and-Kodak-Black","")
    artist = artist.replace("-Featuring-Ed-Sheeran","")
    artist = artist.replace("-Featuring-Kesha","")
    artist = artist.replace("*","")
    artist = artist.replace("A$AP-Ferg","A-ap-ferg")
    artist = artist.replace("-Featuring-Landon-Cube","")
    
  
    song = song.replace("-pt-1","")
    song = song.replace("&","and")
    song = song.replace(" ","-")
    song = song.replace("'","")
    song = song.replace(",","")
    song = song.replace("(","")
    song = song.replace(")","")
    song = song.replace("!","")
    song = song.replace(".","")
    song = song.replace("$ave-Dat","ave-dat")
    print(baseURL+artist+"-"+song+"-lyrics")
    return baseURL+artist+"-"+song+"-lyrics"

# %%
def geniusQuery(songList, artistList):
    n=0
    for each in songList:
        getSongLyrics(each,songURL(artistList[n], each))
        n+=1

# %%
geniusQuery(RapSongs, RapArtists)
# Out:
# https://genius.com/Desiigner-Panda-lyrics
# https://genius.com/Kent-Jones-Dont-Mind-lyrics
# https://genius.com/DJ-Khaled-For-Free-lyrics
# https://genius.com/Future-Low-Life-lyrics
# https://genius.com/Fat-joe-and-remy-ma-All-The-Way-Up-lyrics
# https://genius.com/G-eazy-Me-Myself-and-I-lyrics
# https://genius.com/Drake-Too-Good-lyrics
# https://genius.com/OT-Genasis-Cut-It-lyrics
# https://genius.com/Kevin-Gates-2-Phones-lyrics
# https://genius.com/Drake-Pop-Style-lyrics
# https://genius.com/Future-Wicked-lyrics
# https://genius.com/Kevin-Gates-Really-Really-lyrics
# https://genius.com/MadeinTYO-Uber-Everywhere-lyrics
# https://genius.com/Fetty-Wap-Wake-Up-lyrics
# https://genius.com/Pitbull-Messin-Around-lyrics
# https://genius.com/Drake-Hype-lyrics
# https://genius.com/Drake-Childs-Play-lyrics
# https://genius.com/Drake-Still-Here-lyrics
# https://genius.com/Drake-Grammys-lyrics
# https://genius.com/Belly-Might-Not-lyrics
# https://genius.com/Drake-Feel-No-Ways-lyrics
# https://genius.com/Yo-Gotti-Law-lyrics
# https://genius.com/Kanye-West-Father-Stretch-My-Hands-Pt-1-lyrics
# https://genius.com/Young-Greatness-Moolah-lyrics
# https://genius.com/Chance-The-Rapper-No-Problem-lyrics
# https://genius.com/Drake-Hotline-Bling-lyrics
# https://genius.com/Drake-and-Future-Jumpman-lyrics
# https://genius.com/Post-Malone-White-Iverson-lyrics
# https://genius.com/Travis-Scott-Antidote-lyrics
# https://genius.com/Fetty-Wap-679-lyrics
# https://genius.com/G-eazy-Me-Myself-and-I-lyrics
# https://genius.com/Yo-Gotti-Down-In-The-DM-lyrics
# https://genius.com/Fetty-Wap-Again-lyrics
# https://genius.com/Future-Where-Ya-At-lyrics
# https://genius.com/Young-Thug-Best-Friend-lyrics
# https://genius.com/DLOW-Do-It-Like-Me-lyrics
# https://genius.com/DeJ-Loaf-Back-Up-lyrics
# https://genius.com/iLoveMemphis-Hit-The-Quan-lyrics
# https://genius.com/Drake-and-Future-Big-Rings-lyrics
# https://genius.com/Kevin-Gates-2-Phones-lyrics
# https://genius.com/Missy-Elliott-WTF-Where-They-From-lyrics
# https://genius.com/Lil-Dicky-ave-dat-Money-lyrics
# https://genius.com/Kevin-Gates-Really-Really-lyrics
# https://genius.com/2-Chainz-Watch-Out-lyrics
# https://genius.com/Fetty-Wap-RGF-Island-lyrics
# https://genius.com/Lil-Durk-My-Beyonce-lyrics
# https://genius.com/Colonel-Loud-California-lyrics
rapDf.to_csv("rapLyrics.csv")

# %% [raw]
# rockdata = {'Song': RockSongs, 'Artist': RockArtists, 'Lyrics': songLyrics}

# %%
rockDf = pd.DataFrame(data = rockdata)

# %%
rockDf
# Out:
#                               Artist                                Song
# 0                  twenty one pilots                        Stressed Out
# 1                          Elle King                         Ex's & Oh's
# 2                          James Bay                           Let It Go
# 3                           Coldplay             Adventure Of A Lifetime
# 4                          Disturbed                The Sound Of Silence
# 5                      X Ambassadors                           Renegades
# 6                  twenty one pilots                                Ride
# 7                  Empire Of The Sun                  Walking On A Dream
# 8                      The Lumineers                             Ophelia
# 9                      X Ambassadors                            Unsteady
# 10               Panic! At The Disco                          Victorious
# 11                        Miike Snow                        Genghis Khan
# 12                         Elle King                America's Sweetheart
# 13                          Coldplay                Hymn For The Weekend
# 14               Panic! At The Disco               Emperor's New Clothes
# 15                   The Strumbellas                             Spirits
# 16                          The 1975                           The Sound
# 17               Panic! At The Disco                 Death Of A Bachelor
# 18                             Kaleo                      Way Down We Go
# 19                             Foals                Mountain At My Gates
# 20                         Shinedown                    State Of My Head
# 21               Nothing But Thieves                         Trip Switch
# 22                 Cage The Elephant                         Mess Around
# 23                           BANNERS                        Start A Riot
# 24                            Hozier                 Arsonist's Lullabye
# 25                          The 1975                       Somebody Else
# 26                        The Struts                           Kiss This
# 27                              M83.                       Do It, Try It
# 28           Five Finger Death Punch                    Wash It All Away
# 29               Panic! At The Disco  Don't Threaten Me With A Good Time
# ..                               ...                                 ...
# 70                            MISSIO                      Middle Fingers
# 71                     Cold War Kids                    Love Is Mystical
# 72  Andrew McMahon In The Wilderness                         Fire Escape
# 73                        Papa Roach                                Help
# 74                 Portugal. The Man                       Feel It Still
# 75                             Kaleo                All The Pretty Girls
# 76                        John Mayer                 Love On The Weekend
# 77                            The xx                             On Hold
# 78                      Milky Chance                              Cocoon
# 79                 Cage The Elephant                      Cold Cold Cold
# 80                           Starset                             Monster
# 81         Catfish And The Bottlemen                                   7
# 82                        John Mayer            Still Feel Like Your Man
# 83                       Sylvan Esso                           Die Young
# 84                           Seether                        Let You Down
# 85                              LANY                          Good Girls
# 86                             Spoon                        Hot Thoughts
# 87                         Metallica                        Atlas, Rise!
# 88                         Beartooth                               Hated
# 89                          Bastille                               Blame
# 90                          DREAMERS                      Sweet Disaster
# 91                                LP                         Lost On You
# 92                           Incubus                      Nimble Bastard
# 93                 Breaking Benjamin                         Never Again
# 94                     Maggie Rogers                              Alaska
# 95                         Bob Moses                       Tearing Me Up
# 96                     Bishop Briggs                         Wild Horses
# 97                        Nickelback                    Feed The Machine
# 98                       Mondo Cozmo                               Shine
# 99                     NEEDTOBREATHE                           Hard Love
#
# [100 rows x 2 columns]

# %%
rockDf.to_csv("rockLyrics.csv")

# %% [markdown]
# # Scraping Chinese Lyrics Part 1

# %%
driver = webdriver.Firefox(executable_path=r"E:\geckodriver-v0.19.1-win64\geckodriver.exe")
driver.get("https://music.163.com")
time.sleep(5)

# %%
song_list_bar = [t for t in driver.find_elements_by_tag_name("em") if t.text == "歌单"][0]

# %%
song_list_bar.click()
time.sleep(5)

# %%
# genre_selector = driver.find_element_by_id('g_top')
driver.switch_to_frame('g_iframe')

# %%
genre_selector = driver.find_element_by_id('cateToggleLink')

# %%
genre_selector.click()
time.sleep(5)

# %%
Gufeng_bar = [t for t in driver.find_elements_by_tag_name("a") if t.text == "古风"][0]

# %%
Gufeng_bar.click()

time.sleep(5)

# %%
album_list = [t for t in driver.find_elements_by_tag_name('li') if len(t.text) > 5]
len(album_list)

# %%
album = album_list[5]
album.click()
time.sleep(5)
# print(i.text)

# %%
song_list = driver.find_elements_by_tag_name('b')[3:]
print(len(song_list))
for i in song_list:
    print(i.text,"\n")

# %%
EC.visibility_of_element_located(song_list[13])

# %%
coordinate = "(0,800)"
driver.execute_script('window.scrollBy'+coordinate)

# %%
driver.fullscreen_window()
time.sleep(5)
df_lyrics = pd.DataFrame(columns= ['Song Name', 'Genre', 'Lyrics'])
lyrics_genre = "古风"
lyrics_count = 0
for num in range(len(song_list)):
    print(num)
    if(num >= 11):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 38):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 64):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 91):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 118):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 144):
        driver.execute_script('window.scrollBy(0,800)')
    song_list = driver.find_elements_by_tag_name('b')[3:]
    first_song_bar = song_list[num]
    first_song_bar.click()
    
    time.sleep(2)
    
    if("纯音乐，无歌词" in driver.find_element_by_id('lyric-content').text or "暂时没有歌词" in driver.find_element_by_id('lyric-content').text  ):
        driver.back()
        time.sleep(2)
        continue
    
    for t in driver.find_elements_by_tag_name("a"):
        if "展开" in t.text:
            unfold_bar = t
            unfold_bar.click() 

    
    time.sleep(1)
    lyrics = driver.find_element_by_id('lyric-content').text
    lyrics_name = driver.find_element_by_class_name('tit').text
    song_data = [lyrics_name,lyrics_genre,lyrics]
    df_lyrics.loc[lyrics_count]=song_data
    lyrics_count = lyrics_count+1
#     time.sleep(2)
    driver.back()
    time.sleep(1)

# %%
lyrics_count

# %%
df_lyrics

# %%
df_lyrics.to_csv('Chinese_Gufeng_lyrics.csv', encoding='utf_8_sig', index=False)

# %%
lyrics_data = pd.read_csv('Chinese_Gufeng_lyrics.csv')

# %%
lyrics_data

# %%
driver.back()
time.sleep(2)
album_list = [t for t in driver.find_elements_by_tag_name('li') if len(t.text) > 5]

album = album_list[8]
album.click()
time.sleep(5)
len(album_list)

# %%
print(lyrics_count)
song_list = driver.find_elements_by_tag_name('b')[2:]
print(len(song_list),lyrics_count)
for i in song_list:
    print(i.text,"\n")

# %%
for num in range(len(song_list)):
    print(num)
    print(lyrics_count)
    if(num >= 7):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 35):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 61):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 88):
        driver.execute_script('window.scrollBy(0,800)')
#     if(num >= 117):
#         driver.execute_script('window.scrollBy(0,800)')
#     if(num >= 144):
#         driver.execute_script('window.scrollBy(0,800)')
    song_list = driver.find_elements_by_tag_name('b')[3:]
    first_song_bar = song_list[num]
    first_song_bar.click()
    
    time.sleep(4)
    
    if("纯音乐，无歌词" in driver.find_element_by_id('lyric-content').text or "暂时没有歌词" in driver.find_element_by_id('lyric-content').text  ):
        driver.back()
        time.sleep(2)
        continue
    
    for t in driver.find_elements_by_tag_name("a"):
        if "展开" in t.text:
            unfold_bar = t
            unfold_bar.click() 

    
    time.sleep(1)
    lyrics = driver.find_element_by_id('lyric-content').text
    lyrics_name = driver.find_element_by_class_name('tit').text
    song_data = [lyrics_name,lyrics_genre,lyrics]
    df_lyrics.loc[num+148]=song_data
    lyrics_count = lyrics_count+1
#     time.sleep(2)
    driver.back()
    time.sleep(1)
    if lyrics_count==200:
        break

# %%
df_lyrics

# %%
df_lyrics.to_csv('Chinese_Gufeng_lyrics_1.csv', encoding='utf_8_sig', index=False)

# %%
lyrics_data = pd.read_csv('Chinese_Gufeng_lyrics_1.csv')

# %%
lyrics_data

# %% [markdown]
# # Scraping Chinese Lyrics Part 2

# %%
driver = webdriver.Firefox(executable_path=r"E:\geckodriver-v0.19.1-win64\geckodriver.exe")
driver.get("https://music.163.com")
time.sleep(5)

# %%
song_list_bar = [t for t in driver.find_elements_by_tag_name("em") if t.text == "歌单"][0]

# %%
song_list_bar.click()
time.sleep(5)

# %%
# genre_selector = driver.find_element_by_id('g_top')
driver.switch_to_frame('g_iframe')

# %%
genre_selector = driver.find_element_by_id('cateToggleLink')

# %%
genre_selector.click()
time.sleep(5)

# %%
Minyao_bar = [t for t in driver.find_elements_by_tag_name("a") if t.text == "民谣"][0]

# %%
Minyao_bar.click()

# %%
time.sleep(5)

# %%
album_list = [t for t in driver.find_elements_by_tag_name('li') if len(t.text) > 5]
len(album_list)

# %%
album = album_list[0]
album.click()
time.sleep(5)

# %%
song_list = driver.find_elements_by_tag_name('b')[2:]
print(len(song_list))
for i in song_list:
    print(i.text,"\n")

# %%
driver.execute_script('window.scrollBy(0,800)')

# %%
coordinate = "(0,800)"
driver.execute_script('window.scrollBy'+coordinate)

# %%
driver.fullscreen_window()
time.sleep(5)
df_lyrics = pd.DataFrame(columns= ['Song Name', 'Genre', 'Lyrics'])
lyrics_genre = "民谣"
lyrics_count = 0
for num in range(len(song_list)):
    print(num)
    if(num >= 6):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 33):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 60):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 87):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 114):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 141):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 168):
        driver.execute_script('window.scrollBy(0,800)')
    if(num >= 195):
        driver.execute_script('window.scrollBy(0,800)')
        
    song_list = driver.find_elements_by_tag_name('b')[2:]
    first_song_bar = song_list[num]
    first_song_bar.click()
    
    time.sleep(4)
    
    if("纯音乐，无歌词" in driver.find_element_by_id('lyric-content').text or "暂时没有歌词" in driver.find_element_by_id('lyric-content').text  ):
        driver.back()
        time.sleep(2)
        continue
    
    for t in driver.find_elements_by_tag_name("a"):
        if "展开" in t.text:
            unfold_bar = t
            unfold_bar.click() 

    
    time.sleep(1)
    lyrics = driver.find_element_by_id('lyric-content').text
    lyrics_name = driver.find_element_by_class_name('tit').text
    song_data = [lyrics_name,lyrics_genre,lyrics]
    df_lyrics.loc[lyrics_count]=song_data
    lyrics_count = lyrics_count+1
#     time.sleep(2)
    driver.back()
    time.sleep(1)

# %%
lyrics_count

# %%
df_lyrics

# %%
df_lyrics.to_csv('Chinese_Minyao_lyrics.csv', encoding='utf_8_sig', index=False)

# %%
lyrics_data = pd.read_csv('Chinese_Minyao_lyrics.csv')
