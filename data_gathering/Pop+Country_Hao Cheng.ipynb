# %%
import requests
from bs4 import BeautifulSoup 
import json
import pandas as pd
import re

# %% [markdown]
# # Pop songs

# %%
url1 = 'https://genius.com/api/songs/chart?page='
url2 = '&per_page=10&tag_id=16&time_period=day'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36',
}

df_pop = pd.DataFrame(columns= ['Song_Name', 'Artist','Genre', 'Lyrics'])

for x in range(1,11):
    json_pop = requests.get(url1+ str(x) + url2, headers = headers).content
    
    
    con=json.loads(json_pop)

#     for t in range(0,9):
    lyrics_List= con["response"]["chart_items"]
    
    for item in lyrics_List:
        
        url= item['item']['url']   
        html = requests.get(url, headers = headers).content
        soup = BeautifulSoup(html,'html.parser')
        

        lyrics_list_soup = soup.find('div', attrs={'class': 'lyrics'})
        
        if(lyrics_list_soup.p is not None):
            lyrics1_list_soup = lyrics_list_soup.find('p').getText()
            if(lyrics1_list_soup == ""):
                lyrics1_list_soup = "no lyrics"
        else:
            lyrics1_list_soup = "no lyrics"

        Song_Name = soup.find('h1', attrs = {'class' : 'header_with_cover_art-primary_info-title'}).getText()
        artist_list_soup = soup.find('h2')
        Artist = artist_list_soup.find('a', attrs = {'class' : 'header_with_cover_art-primary_info-primary_artist'}).getText()
        Genre = "Pop"
        Lyrics = lyrics1_list_soup

#         lyrics_data = [Song_Name, Artist, Genre, Lyrics]
#         print(lyrics_data)
    
        df_pop.loc[len(df_pop)] = [Song_Name, Artist,Genre, Lyrics]
df_pop

# output =  df_pop.to_json(orient='records')
# with open('lyrics_pop.json', 'w') as f:
#     f.write(output)
# Out:
#                                             Song_Name  \
# 0                                No Tears Left to Cry
# 1                                             FRIENDS
# 2                                    A Million Dreams
# 3                                          The Middle
# 4                                   Rewrite the Stars
# 5                                             ​lovely
# 6                                          Be Careful
# 7                                     Te Boté (Remix)
# 8                                            One Kiss
# 9                                                SAD!
# 10                                                OTW
# 11                                        Hasta Luego
# 12                                        Take a Byte
# 13                               Crazy, Classic, Life
# 14                                               Ring
# 15                                         Youngblood
# 16                                       Barbie Tingz
# 17                                    Thru Your Phone
# 18                                           Somebody
# 19                                     1-800-273-8255
# 20                                          Bom Diggy
# 21                                              Bukti
# 22                                            Perfect
# 23                                    I Got the Juice
# 24                   Raat Kamaal Hai 320Kbps MP3 Song
# 25                                               Mine
# 26                                          X (EQUIS)
# 27                                    Finesse (Remix)
# 28                                               Baby
# 29                                  The Greatest Show
# ..                                                ...
# 70                               Too Good at Goodbyes
# 71                                      Hair Too Long
# 72                                           Believer
# 73                                    Raat Kamaal Hai
# 74                                    Globglogabgalab
# 75                                         The Nights
# 76                                Hard 2 Face Reality
# 77                                       Kathang Isip
# 78  Becky G & Natti Natasha - Sin Pijama (English ...
# 79                                   Kekasih Bayangan
# 80                     First Place (The Race - Remix)
# 81                                               Hola
# 82                                     The Other Side
# 83                                          Sunflower
# 84                          Hon Dansar Vidare I Livet
# 85                                            Revenge
# 86                                      Say Something
# 87                                         Come Alive
# 88                                         The A Team
# 89                                    Intro: Euphoria
# 90                                        Without You
# 91                                            Lo malo
# 92                                     Don't Leave Me
# 93                                          Super Far
# 94                                         These Days
# 95                                               Burn
# 96                                          Guatemala
# 97                                          Love Lies
# 98                                          All of Me
# 99                               The Schuyler Sisters
#
#                                    Artist Genre  \
# 0                           Ariana Grande   Pop
# 1                 Marshmello & Anne-Marie   Pop
# 2                             Ziv Zaifman   Pop
# 3                                    Zedd   Pop
# 4                               Zac Efron   Pop
# 5                  Billie Eilish & Khalid   Pop
# 6                                 Cardi B   Pop
# 7   Nio García, Casper Mágico & Bad Bunny   Pop
# 8                Calvin Harris & Dua Lipa   Pop
# 9                            XXXTENTACION   Pop
# 10          Khalid, 6LACK & Ty Dolla $ign   Pop
# 11                    HRVY & Malu Trevejo   Pop
# 12                          Janelle Monáe   Pop
# 13                          Janelle Monáe   Pop
# 14                                Cardi B   Pop
# 15                    5 Seconds of Summer   Pop
# 16                            Nicki Minaj   Pop
# 17                                Cardi B   Pop
# 18                       The Chainsmokers   Pop
# 19                                  Logic   Pop
# 20             Zack Knight & Jasmin Walia   Pop
# 21                                Virgoun   Pop
# 22                             Ed Sheeran   Pop
# 23                          Janelle Monáe   Pop
# 24             Guru Randhawa, Tulsi Kumar   Pop
# 25                                  Bazzi   Pop
# 26                   Nicky Jam & J Balvin   Pop
# 27                             Bruno Mars   Pop
# 28                          Justin Bieber   Pop
# 29                           Hugh Jackman   Pop
# ..                                    ...   ...
# 70                              Sam Smith   Pop
# 71                              The Vamps   Pop
# 72                        Imagine Dragons   Pop
# 73                          Guru Randhawa   Pop
# 74                          Tony Halstead   Pop
# 75                                 Avicii   Pop
# 76                               Poo Bear   Pop
# 77                            Ben and Ben   Pop
# 78                    Genius Translations   Pop
# 79                             Cakra Khan   Pop
# 80                                 Larray   Pop
# 81                                Shelita   Pop
# 82                           Hugh Jackman   Pop
# 83                      Rex Orange County   Pop
# 84                                   HOV1   Pop
# 85                           XXXTENTACION   Pop
# 86                      Justin Timberlake   Pop
# 87                           Hugh Jackman   Pop
# 88                             Ed Sheeran   Pop
# 89                                    BTS   Pop
# 90                                 Avicii   Pop
# 91                    Aitana & Ana Guerra   Pop
# 92                                    BTS   Pop
# 93                                   LANY   Pop
# 94                             Rudimental   Pop
# 95                     Lin-Manuel Miranda   Pop
# 96    Swae Lee, Slim Jxmmi & Rae Sremmurd   Pop
# 97                       Khalid & Normani   Pop
# 98                            John Legend   Pop
# 99                     Lin-Manuel Miranda   Pop
#
#                                                Lyrics
# 0   [Intro]\nRight now, I'm in a state of mind\nI ...
# 1   [Intro: Anne-Marie]\nOoooh-oh, ooooh-woh\nOooo...
# 2   [YOUNG P.T.]\nI close my eyes and I can see\nT...
# 3   [Verse 1: Maren Morris]\nTake a seat\nRight ov...
# 4   [Verse 1: Phillip Carlyle]\nYou know I want yo...
# 5   [Verse 1: Billie Eilish & Khalid]\nThought I f...
# 6   [Intro]\nYeah\nCare for me, care for me, care ...
# 7                                           no lyrics
# 8   [Chorus]\nOne kiss is all it takes\nFallin' in...
# 9   [Intro]\n(Yeah)\n\n[Chorus]\nWho am I? Someone...
# 10  [Intro: Khalid]\nNa, na, na, na, ooh\nOh, no, ...
# 11  [Verse 1: HRVY]\nYou got them Juliet eyes\nAn ...
# 12  [Verse 1]\nI'm not the kind of girl you take h...
# 13  [Intro]\nYou told us we hold these truths to b...
# 14  [Intro: Kehlani]\nOoh, ooh\nRing, ring, ring, ...
# 15  [Verse 1]\nRemember the words you told me, "Lo...
# 16  [Intro]\nDem-dem-dem-dem dem-dem\nDem-dem-dem-...
# 17  [Verse 1: Cardi B]\nLook, I just want to break...
# 18  [Chorus: Drew Love]\nIn the town full of fancy...
# 19  [Pre-Chorus: Logic]\nI've been on the low\nI b...
# 20  [Intro: Jasmin Walia]\nBoy, you don't have to ...
# 21  [Verse 1]\nMemenangkan hatiku\nBukanlah satu h...
# 22  [Verse 1]\nI found a love for me\nOh darling, ...
# 23  [Verse 1: Janelle Monáe]\nYou're so damn elect...
# 24  320Kbps Song Download\n\nRaat Kamaal Hai - Gur...
# 25  [Intro]\nHuh, yeah, naw I just, had a lil' bit...
# 26                                          no lyrics
# 27  [Verse 1: Cardi B]\nDrop top Porsche (Porsche)...
# 28  [Produced by The-Dream and Tricky Stewart]\n\n...
# 29  [ENSEMBLE]\nWoah\nWoah\nWoah\nWoah\nWoah\nWoah...
# ..                                                ...
# 70  [Verse 1]\nYou must think that I'm stupid\nYou...
# 71  [Verse 1]\nI'm just sick of staying up losing ...
# 72  [Verse 1]\nFirst things first\nI'ma say all th...
# 73  Raat Kamaal Hai - Guru Randhawa Mp3 Song\n\nRa...
# 74  [Intro]\nI'm the Globglogabgalab\nI love books...
# 75  [Verse 1]\nOnce upon a younger year\nWhen all ...
# 76  [Chorus: Poo Bear]\nSometimes it's hard to fac...
# 77  [Verse 1]\nDiba nga ito ang iyong gusto?\nO, i...
# 78  [Intro: Becky G, Natti Natasha]\n[You are] alo...
# 79  [Verse 1]\nPadamu pemilik hati yang tak pernah...
# 80  [Intro]\nYo, Larray, ok, skrt, skrt, ooh, bang...
# 81  I’m gonna hold you ‘til this song’s over\nHola...
# 82  [Verse 1: P.T. Barnum]\nRight here, right now\...
# 83  [Intro]\nI want to know\nWhere I can go\nWhen ...
# 84  [Vers 1: Noel Flike]\nNu står hon där med vits...
# 85  [Intro]\nI think I, I think I finally\nFound a...
# 86  [Intro: Justin Timberlake]\nMhmm, yeah, alrigh...
# 87  [Verse 1: P.T. Barnum]\nYou stumble through yo...
# 88  [Verse 1]\nWhite lips, pale face\nBreathing in...
# 89                                          no lyrics
# 90  [Verse 1]\nYou said that we would always be\nW...
# 91                                          no lyrics
# 92  君の言葉には\nいくつの意味が\nあるように聞こえるから\nWhat is what?\n\...
# 93  [Verse 1]\nUp all night on my mind got me thin...
# 94  [Intro: Macklemore]\nI know you moved onto som...
# 95  [ELIZA]\nI saved every letter you wrote me\nFr...
# 96  [Intro: Swae Lee]\nOh, oh, oh-oh\nSeen the way...
# 97  [Verse 1: Khalid]\nSorry if it's hard to catch...
# 98  [Verse 1]\nWhat would I do without your smart ...
# 99  [BURR]\nThere’s nothing rich folks love more\n...
#
# [100 rows x 4 columns]

# %%
# https://genius.com/api/songs/chart?page=1&per_page=10&tag_id=16&time_period=month
url1 = 'https://genius.com/api/songs/chart?page='
url2 = '&per_page=10&tag_id=16&time_period=month'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36',
}

df_pop1 = pd.DataFrame(columns= ['Song_Name', 'Artist','Genre', 'Lyrics'])

for x in range(1,11):
    json_pop1 = requests.get(url1+ str(x) + url2, headers = headers).content
    
    
    con=json.loads(json_pop1)

#     for t in range(0,9):
    lyrics_List= con["response"]["chart_items"]
    
    for item in lyrics_List:
        
        url= item['item']['url']   
        html = requests.get(url, headers = headers).content
        soup = BeautifulSoup(html,'html.parser')
        

        lyrics_list_soup = soup.find('div', attrs={'class': 'lyrics'})
        
        if(lyrics_list_soup.p is not None):
            lyrics1_list_soup = lyrics_list_soup.find('p').getText()
            if(lyrics1_list_soup == ""):
                lyrics1_list_soup = "no lyrics"
        else:
            lyrics1_list_soup = "no lyrics"

        Song_Name = soup.find('h1', attrs = {'class' : 'header_with_cover_art-primary_info-title'}).getText()
        artist_list_soup = soup.find('h2')
        Artist = artist_list_soup.find('a', attrs = {'class' : 'header_with_cover_art-primary_info-primary_artist'}).getText()
        Genre = "Pop"
        Lyrics = lyrics1_list_soup

#         lyrics_data = [Song_Name, Artist, Genre, Lyrics]
#         print(lyrics_data)
    
        df_pop1.loc[len(df_pop1)] = [Song_Name, Artist,Genre, Lyrics]
df_pop1
# Out:
#                          Song_Name                                 Artist  \
# 0                       Be Careful                                Cardi B
# 1                          FRIENDS                Marshmello & Anne-Marie
# 2                     Wasted Times                             The Weeknd
# 3             No Tears Left to Cry                          Ariana Grande
# 4                             SAD!                           XXXTENTACION
# 5                 A Million Dreams                            Ziv Zaifman
# 6                     Barbie Tingz                            Nicki Minaj
# 7                  Thru Your Phone                                Cardi B
# 8                Rewrite the Stars                              Zac Efron
# 9                           Let Me                                   ZAYN
# 10                            Ring                                Cardi B
# 11               The Greatest Show                           Hugh Jackman
# 12                      The Middle                                   Zedd
# 13                 Te Boté (Remix)  Nio García, Casper Mágico & Bad Bunny
# 14                        One Kiss               Calvin Harris & Dua Lipa
# 15                  1-800-273-8255                                  Logic
# 16                            Mine                                  Bazzi
# 17                       Bom Diggy             Zack Knight & Jasmin Walia
# 18                 Finesse (Remix)                             Bruno Mars
# 19                         Perfect                             Ed Sheeran
# 20                   Lost in Japan                           Shawn Mendes
# 21                      This Is Me                           Keala Settle
# 22                      Youngblood                    5 Seconds of Summer
# 23                           Bukti                                Virgoun
# 24              You Are the Reason                            Calum Scott
# 25                   All the Stars                   Kendrick Lamar & SZA
# 26                  Don't Leave Me                                    BTS
# 27                        Amorfoda                              Bad Bunny
# 28               Despacito (Remix)              Luis Fonsi & Daddy Yankee
# 29                            PYNK                          Janelle Monáe
# ..                             ...                                    ...
# 70                        Somebody                       The Chainsmokers
# 71                        Medicine                           Harry Styles
# 72                      These Days                             Rudimental
# 73  First Place (The Race - Remix)                                 Larray
# 27   Pop                                          no lyrics
# 28   Pop                                          no lyrics
# 29   Pop  [Verse 1: Janelle Monáe]\nPynk, like the insid...
# ..   ...                                                ...
# 70   Pop  [Chorus: Drew Love]\nIn the town full of fancy...
# 71   Pop  [Verse 1]\nHere to take my medicine, take my m...
# 72   Pop  [Intro: Macklemore]\nI know you moved onto som...
# 73   Pop  [Intro]\nYo, Larray, ok, skrt, skrt, ooh, bang...
# 74   Pop  Una mattina mi son svegliato\nO bella, ciao! b...
# 75   Pop  [Intro]\nI want to know\nWhere I can go\nWhen ...
# 76   Pop  [Verse 1: Sugarland]\nWhat a shame\nDidn't wan...
# 77   Pop  [Chorus: Poo Bear]\nSometimes it's hard to fac...
# 78   Pop  [Verse 1]\nI will always remember\nThe day you...
# 79   Pop  [Intro: Justin Timberlake]\nMhmm, yeah, alrigh...
# 80   Pop  [Intro]\nThis ain't for the best\nMy reputatio...
# 81   Pop  [Intro]\nDicke, dicke Lippen, dicke Lippen, di...
# 82   Pop  [Verse 1]\nLovin' you is like a fairytale\nI j...
# 83   Pop  [Verse 1]\nUp all night on my mind got me thin...
# 84   Pop  [Verse 1]\nCan't keep my hands to myself\nThin...
# 85   Pop  [Verse 1: P.T. Barnum]\nI saw the sun begin to...
# 86   Pop  [Verse 1]\nPagi ke pagi ku terjebak di dalam a...
# 87   Pop  [ELIZA]\nI saved every letter you wrote me\nFr...
# 88   Pop  [Verse 1]\nRobert's got a quick hand\nHe'll lo...
# 89   Pop  [Intro: T-Pain + (Flo Rida)]\nHmm-mmm-mmm-mmm-...
# 90   Pop  [BURR]\nThere’s nothing rich folks love more\n...
# 91   Pop  [Intro: Charlie Puth]\nOh, oh\n\n[Verse 1: Cha...
# 92   Pop  [Verse 1]\nWhat would I do without your smart ...
# 93   Pop  [Official Music Video]\n[Aloe Blacc Music Vide...
# 94   Pop  [Intro]\nIs this the real life? Is this just f...
# 95   Pop  [Verse 1]\nI've missed your calls for months i...
# 96   Pop  [Produced by Greg Kurstin and Jesse Shatkin]\n...
# 97   Pop  [Verse 1]\nIt could change, but this feels lik...
# 98   Pop  [Intro: Drew Taggart]\nYeah, let's do it again...
# 99   Pop  The other night dear, as I lay sleeping\nI dre...
#
# [100 rows x 4 columns]

# %%
# https://genius.com/api/songs/chart?page=1&per_page=10&tag_id=16&time_period=all_time
url1 = 'https://genius.com/api/songs/chart?page='
url2 = '&per_page=10&tag_id=16&time_period=all_time'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36',
}

df_pop2 = pd.DataFrame(columns= ['Song_Name', 'Artist','Genre', 'Lyrics'])

for x in range(1,11):
    json_pop2 = requests.get(url1+ str(x) + url2, headers = headers).content
    
    
    con=json.loads(json_pop2)

#     for t in range(0,9):
    lyrics_List= con["response"]["chart_items"]
    
    for item in lyrics_List:
        
        url= item['item']['url']   
        html = requests.get(url, headers = headers).content
        soup = BeautifulSoup(html,'html.parser')
        

        lyrics_list_soup = soup.find('div', attrs={'class': 'lyrics'})
        
        if(lyrics_list_soup.p is not None):
            lyrics1_list_soup = lyrics_list_soup.find('p').getText()
            if(lyrics1_list_soup == ""):
                lyrics1_list_soup = "no lyrics"
        else:
            lyrics1_list_soup = "no lyrics"

        Song_Name = soup.find('h1', attrs = {'class' : 'header_with_cover_art-primary_info-title'}).getText()
        artist_list_soup = soup.find('h2')
        Artist = artist_list_soup.find('a', attrs = {'class' : 'header_with_cover_art-primary_info-primary_artist'}).getText()
        Genre = "Pop"
        Lyrics = lyrics1_list_soup

#         lyrics_data = [Song_Name, Artist, Genre, Lyrics]
#         print(lyrics_data)
    
        df_pop2.loc[len(df_pop2)] = [Song_Name, Artist,Genre, Lyrics]
df_pop2
# Out:
#                             Song_Name                     Artist Genre  \
# 0                   Despacito (Remix)  Luis Fonsi & Daddy Yankee   Pop
# 1                        Shape of You                 Ed Sheeran   Pop
# 2                       Drunk in Love                    Beyoncé   Pop
# 3                           The Hills                 The Weeknd   Pop
# 4                                Work                    Rihanna   Pop
# 5                Too Good at Goodbyes                  Sam Smith   Pop
# 6                       Hotline Bling                      Drake   Pop
# 7                              Closer           The Chainsmokers   Pop
# 8                      1-800-273-8255                      Logic   Pop
# 9                             Starboy                 The Weeknd   Pop
# 10                          One Dance                      Drake   Pop
# 11                          FORMATION                    Beyoncé   Pop
# 12                        I'm the One                  DJ Khaled   Pop
# 13               ​i​ hate u, i love u                     ​gnash   Pop
# 14                            Perfect                 Ed Sheeran   Pop
# 15                      Blurred Lines               Robin Thicke   Pop
# 16                        The Monster                     Eminem   Pop
# 17                              ​iSpy                       KYLE   Pop
# 18                        Thrift Shop    Macklemore & Ryan Lewis   Pop
# 19                              Hello                      Adele   Pop
# 20                          Get Lucky                  Daft Punk   Pop
# 21                 Can't Feel My Face                 The Weeknd   Pop
# 22                          New Rules                   Dua Lipa   Pop
# 23                      Love Yourself              Justin Bieber   Pop
# 24                      See You Again                Wiz Khalifa   Pop
# 25                          Attention               Charlie Puth   Pop
# 26                      Can't Hold Us    Macklemore & Ryan Lewis   Pop
# 27                           Believer            Imagine Dragons   Pop
# 28                            7 Years               Lukas Graham   Pop
# 29                    Let Me Love You                   DJ Snake   Pop
# ..                                ...                        ...   ...
# 70                             Famous                 Kanye West   Pop
# 71                              Happy          Pharrell Williams   Pop
# 72                  Take Me to Church                     Hozier   Pop
# 73                            Revenge               XXXTENTACION   Pop
# 74                    Sorry Not Sorry                Demi Lovato   Pop
# 75               The Schuyler Sisters         Lin-Manuel Miranda   Pop
# 76                 Castle on the Hill                 Ed Sheeran   Pop
# 77                  Love on the Brain                    Rihanna   Pop
# 78                   I Feel It Coming                 The Weeknd   Pop
# 79                     Dusk Till Dawn                       ZAYN   Pop
# 80  More Life [Tracklist + Cover Art]                      Drake   Pop
# 81                  The Greatest Show               Hugh Jackman   Pop
# 82                             Royals                      Lorde   Pop
# 83                    How Far I'll Go        Walt Disney Records   Pop
# 84                        Titibo-tibo           Moira Dela Torre   Pop
# 85                            Mirrors          Justin Timberlake   Pop
# 86                     You'll Be Back         Lin-Manuel Miranda   Pop
# 87                              Power                 Kanye West   Pop
# 79  [Verse 1: ZAYN]\nNot tryna be indie\nNot tryna...
# 80  Tracklist (click links to display lyrics)\n1. ...
# 81  [ENSEMBLE]\nWoah\nWoah\nWoah\nWoah\nWoah\nWoah...
# 82  [Produced by Joel Little]\n[Video by Joel Kefa...
# 83  [Verse 1]\nI've been staring at the edge of th...
# 84                                          no lyrics
# 85  [Verse 1]\nAren't you somethin' to admire\n'Ca...
# 86  [Verse 1: KING GEORGE]\nYou say\nThe price of ...
# 87  [Produced by Andrew Dawson, Jeff Bhasker, Kany...
# 88  [Written by Alessia Cara & Sebastian Kole]\n[P...
# 89  [Verse 1]\nIt was great at the very start\nHan...
# 90  [Intro: Nicki Minaj]\nDrank\nYoung Money\n\n[V...
# 91                                          no lyrics
# 92  [Intro: Quavo]\nHuncho\nQuavo\nYo yo\n\n[Verse...
# 93  [Produced by Daft Punk, Julian Casablancas, Jo...
# 94  [Verse 1: Adam Levine]\nSay say say, hey hey n...
# 95  [Refrain]\nThey know what is what\nBut they do...
# 96  [Chorus]\nHold up, they don't love you like I ...
# 97  [Verse 1]\nI took a pill in Ibiza\nTo show Avi...
# 98  [Intro: Justin Bieber]\nAs long as you love me...
# 99  [ELIZA]\nI saved every letter you wrote me\nFr...
#
# [100 rows x 4 columns]

# %%
frames = [df_pop, df_pop1, df_pop2]
result = pd.concat(frames)
result[:]
# Out:
#                             Song_Name                                 Artist  \
# 0                No Tears Left to Cry                          Ariana Grande
# 1                             FRIENDS                Marshmello & Anne-Marie
# 2                    A Million Dreams                            Ziv Zaifman
# 3                          The Middle                                   Zedd
# 4                   Rewrite the Stars                              Zac Efron
# 5                             ​lovely                 Billie Eilish & Khalid
# 6                          Be Careful                                Cardi B
# 7                     Te Boté (Remix)  Nio García, Casper Mágico & Bad Bunny
# 8                            One Kiss               Calvin Harris & Dua Lipa
# 9                                SAD!                           XXXTENTACION
# 10                                OTW          Khalid, 6LACK & Ty Dolla $ign
# 11                        Hasta Luego                    HRVY & Malu Trevejo
# 12                        Take a Byte                          Janelle Monáe
# 13               Crazy, Classic, Life                          Janelle Monáe
# 14                               Ring                                Cardi B
# 15                         Youngblood                    5 Seconds of Summer
# 16                       Barbie Tingz                            Nicki Minaj
# 17                    Thru Your Phone                                Cardi B
# 18                           Somebody                       The Chainsmokers
# 19                     1-800-273-8255                                  Logic
# 20                          Bom Diggy             Zack Knight & Jasmin Walia
# 21                              Bukti                                Virgoun
# 22                            Perfect                             Ed Sheeran
# 23                    I Got the Juice                          Janelle Monáe
# 24   Raat Kamaal Hai 320Kbps MP3 Song             Guru Randhawa, Tulsi Kumar
# 25                               Mine                                  Bazzi
# 26                          X (EQUIS)                   Nicky Jam & J Balvin
# 27                    Finesse (Remix)                             Bruno Mars
# 28                               Baby                          Justin Bieber
# 29                  The Greatest Show                           Hugh Jackman
# ..                                ...                                    ...
# 70                             Famous                             Kanye West
# 71                              Happy                      Pharrell Williams
# 72                  Take Me to Church                                 Hozier
# 73                            Revenge                           XXXTENTACION
# 26   Pop                                          no lyrics
# 27   Pop  [Verse 1: Cardi B]\nDrop top Porsche (Porsche)...
# 28   Pop  [Produced by The-Dream and Tricky Stewart]\n\n...
# 29   Pop  [ENSEMBLE]\nWoah\nWoah\nWoah\nWoah\nWoah\nWoah...
# ..   ...                                                ...
# 70   Pop  [Intro: Rihanna & Kanye West]\nMan I can under...
# 71   Pop  [Produced by Pharrell Williams]\n\n[Verse 1]\n...
# 72   Pop  [Produced by Hozier and Rob Kirwan]\n\n[Video ...
# 73   Pop  [Intro]\nI think I, I think I finally\nFound a...
# 74   Pop  [Intro]\nPayback is a bad bitch\nAnd baby, I'm...
# 75   Pop  [BURR]\nThere’s nothing rich folks love more\n...
# 76   Pop  [Verse 1]\nWhen I was six years old I broke my...
# 77   Pop  [Verse 1]\nAnd you got me like, "Oh, what you ...
# 78   Pop  [Intro: The Weeknd]\nYeah, uh\n\n[Verse 1: The...
# 79   Pop  [Verse 1: ZAYN]\nNot tryna be indie\nNot tryna...
# 80   Pop  Tracklist (click links to display lyrics)\n1. ...
# 81   Pop  [ENSEMBLE]\nWoah\nWoah\nWoah\nWoah\nWoah\nWoah...
# 82   Pop  [Produced by Joel Little]\n[Video by Joel Kefa...
# 83   Pop  [Verse 1]\nI've been staring at the edge of th...
# 84   Pop                                          no lyrics
# 85   Pop  [Verse 1]\nAren't you somethin' to admire\n'Ca...
# 86   Pop  [Verse 1: KING GEORGE]\nYou say\nThe price of ...
# 87   Pop  [Produced by Andrew Dawson, Jeff Bhasker, Kany...
# 88   Pop  [Written by Alessia Cara & Sebastian Kole]\n[P...
# 89   Pop  [Verse 1]\nIt was great at the very start\nHan...
# 90   Pop  [Intro: Nicki Minaj]\nDrank\nYoung Money\n\n[V...
# 91   Pop                                          no lyrics
# 92   Pop  [Intro: Quavo]\nHuncho\nQuavo\nYo yo\n\n[Verse...
# 93   Pop  [Produced by Daft Punk, Julian Casablancas, Jo...
# 94   Pop  [Verse 1: Adam Levine]\nSay say say, hey hey n...
# 95   Pop  [Refrain]\nThey know what is what\nBut they do...
# 96   Pop  [Chorus]\nHold up, they don't love you like I ...
# 97   Pop  [Verse 1]\nI took a pill in Ibiza\nTo show Avi...
# 98   Pop  [Intro: Justin Bieber]\nAs long as you love me...
# 99   Pop  [ELIZA]\nI saved every letter you wrote me\nFr...
#
# [300 rows x 4 columns]

# %%
result.to_csv('lyrics_pop_300.csv',sep=',')

# %% [markdown]
# # Country

# %%
# https://genius.com/api/songs/chart?page=1&per_page=10&tag_id=413&time_period=day
url1 = 'https://genius.com/api/songs/chart?page='
url2 = '&tag_id=413&time_period=day'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36',
}

df_country = pd.DataFrame(columns= ['Song_Name', 'Artist', 'Genre', 'Lyrics'])

for x in range(1,15):
    json_country = requests.get(url1+ str(x) + url2, headers = headers).content
    
    
    con=json.loads(json_country)

#     for t in range(0,9):
    lyrics_List= con["response"]["chart_items"]
    
    for item in lyrics_List:
        
        url= item['item']['url']   
        html = requests.get(url, headers = headers).content
        soup = BeautifulSoup(html,'html.parser')
        

        lyrics_list_soup = soup.find('div', attrs={'class': 'lyrics'})
        
        if(lyrics_list_soup.p is not None):
            lyrics1_list_soup = lyrics_list_soup.find('p').getText()
            if(lyrics1_list_soup == ""):
                lyrics1_list_soup = "no lyrics"
        else:
            lyrics1_list_soup = "no lyrics"

        Song_Name = soup.find('h1', attrs = {'class' : 'header_with_cover_art-primary_info-title'}).getText()
        artist_list_soup = soup.find('h2')
        Artist = artist_list_soup.find('a', attrs = {'class' : 'header_with_cover_art-primary_info-primary_artist'}).getText()
        Genre = "country"
        Lyrics = lyrics1_list_soup

        lyrics_data = [Song_Name, Artist, Genre, Lyrics]
#         print(lyrics_data)
    

        df_country.loc[len(df_country)] = [Song_Name, Artist, Genre, Lyrics]
df_country
# Out:
#                                      Song_Name  \
# 0                               Lovesick Blues
# 1    Chootay Maatay Mp3 Song Download Djpunjab
# 2                                         Babe
# 3                          You Are My Sunshine
# 4                                Say Something
# 5                                   Cry Pretty
# 6                   Can't Help Falling In Love
# 7                                  Meant to Be
# 8                                       Jolene
# 9                                         Stay
# 10                                       Mercy
# 11                   Something You Get Through
# 12             In Hell I'll Be in Good Company
# 13                                    What Ifs
# 14                                 Самая вышка
# 15                                   Get Along
# 16                 Take Me Home, Country Roads
# 17                                        Hurt
# 18                                Take It Easy
# 19       Lovesick Blues (Walmart yodeling kid)
# 20                             Whiskey Lullaby
# 21                            You Make It Easy
# 22                        Most People Are Good
# 23                                 Coming Home
# 24                               Broken Arrows
# 25                          Smokin' and Cryin'
# 26                                Life Changes
# 27                                      Heaven
# 28                    Oh My Darling Clementine
# 29                                    Criminal
# ..                                         ...
# 90                        Stop Me from Falling
# 91                           I'll Wait for You
# 92                                 Wagon Wheel
# 93                                  Better Man
# 94                                   Fireworks
# 95                          Dalgalan Karadeniz
# 96                                       Woman
# 97                                  Hangin' On
# 98                              Singles You Up
# 99                      Right Girl, Wrong Time
# 100                                   Lady May
# 101                     When It Rains It Pours
# 102                                  Enchanted
# 103                              Run Devil Run
# 104                                    My Girl
# 105                                Heart Break
# 106                            The Older I Get
# 107                              Unforgettable
# 108                             Man Enough Now
# 109                            I Walk The Line
# 110                        Folsom Prison Blues
# 111                            Die a Happy Man
# 112                     Everything Has Changed
# 113                           American Scandal
# 114                  Knockin' On Heaven's Door
# 115                                   Your Man
# 116                        Hippies and Cowboys
# 117                            Hello Beautiful
# 118                               Müzik Kutusu
# 119                               Broken Halos
#
#                                Artist    Genre  \
# 0                       Hank Williams  country
# 1                                Guri  country
# 2                           Sugarland  country
# 3                         Johnny Cash  country
# 4                   Justin Timberlake  country
# 5                    Carrie Underwood  country
# 6                       Elvis Presley  country
# 7                          Bebe Rexha  country
# 8                        Dolly Parton  country
# 9                         Post Malone  country
# 10                        Brett Young  country
# 11                      Willie Nelson  country
# 12                     The Dead South  country
# 13                         Kane Brown  country
# 14                       Raim & Artur  country
# 15                      Kenny Chesney  country
# 16                        John Denver  country
# 17                        Johnny Cash  country
# 18                             Eagles  country
# ..                                                 ...
# 90   [Verse 1]\nSomehow we've always been together\...
# 91   [Verse 1]\nThese fields don't grow overnight, ...
# 92   [Verse 1]\nHeading down south to the land of t...
# 93   [Verse 1]\nI know I’m probably better off on m...
# 94   [Verse 1]\nI could've sworn I saw fireworks\nF...
# 95   Karadeniz puslidur\nBulutlara yaslidur\nDenizu...
# 96   [Intro]\nLet's be serious, come on\nThis is a ...
# 97   [Verse 1]\nI'm a few drinks in, but that ain't...
# 98   [Verse 1]\nI ain't heard you laugh like that i...
# 99   [Verse 1]\nShe talked with a drawl\nHad me wra...
# 100  I'm a stone's throw from the mill\nAnd I'm a g...
# 101  [Verse 1]\nSunday morning man\nShe woke up fig...
# 102  [Verse 1]\nThere I was again tonight\nForcing ...
# 103  [Intro]\nRun devil, run devil\nRun devil, run\...
# 104  [Verse 1]\nShe looks so pretty with no makeup ...
# 105  [Verse 1]\nI paint my lips red, I turn my own ...
# 106  [Verse 1]\nThe older I get\nThe more I think\n...
# 107  [Verse 1]\nIt was the 14th of October\nHad tha...
# 108  [Verse 1]\nI was scared, I wasn't quite ready ...
# 109  [Chorus]\nI keep a close watch on this heart o...
# 110  I hear the train a comin', it's rolling 'round...
# 111  [Verse 1]\nBaby last night was hands down\nOne...
# 112  [Verse 1: Taylor Swift]\nAll I knew this morni...
# 113  [Verse 1]\nChecking my lipstick in your aviato...
# 114  [Harmonica Solo]\n\n[Verse 1]\nMama, take this...
# 115  [Verse 1]\nBaby lock the door and turn the lig...
# 116  Well I started on the whiskey pretty early thi...
# 117  I was eighteen when we first met\nCouldn’t bel...
# 118  Ben bir ayyaşım\nSekiz çizer ayaklarım\nÖzlemi...
# 119  [Refrain]\nSeen my share of broken halos\nFold...
#
# [120 rows x 4 columns]

# %%
#https://genius.com/api/songs/chart?page=1&per_page=10&tag_id=413&time_period=all_time
url1 = 'https://genius.com/api/songs/chart?page='
url2 = '&per_page=10&tag_id=413&time_period=all_time'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36',
}

df_country1 = pd.DataFrame(columns= ['Song_Name', 'Artist', 'Genre', 'Lyrics'])

for x in range(1,11):
    json_country1 = requests.get(url1+ str(x) + url2, headers = headers).content
    
    
    con=json.loads(json_country1)

#     for t in range(0,9):
    lyrics_List= con["response"]["chart_items"]
    
    for item in lyrics_List:
        
        url= item['item']['url']   
        html = requests.get(url, headers = headers).content
        soup = BeautifulSoup(html,'html.parser')
        

        lyrics_list_soup = soup.find('div', attrs={'class': 'lyrics'})
        
        if(lyrics_list_soup.p is not None):
            lyrics1_list_soup = lyrics_list_soup.find('p').getText()
            if(lyrics1_list_soup == ""):
                lyrics1_list_soup = "no lyrics"
        else:
            lyrics1_list_soup = "no lyrics"

        Song_Name = soup.find('h1', attrs = {'class' : 'header_with_cover_art-primary_info-title'}).getText()
        artist_list_soup = soup.find('h2')
        Artist = artist_list_soup.find('a', attrs = {'class' : 'header_with_cover_art-primary_info-primary_artist'}).getText()
        Genre = "country"
        Lyrics = lyrics1_list_soup

        lyrics_data = [Song_Name, Artist, Genre, Lyrics]
# 55  country  [Verse 1]\nShe wants to get married, she wants...
# 56  country  [Intro]\nDaylight, woah daylight\nDaylight, is...
# 57  country  You're stubborn as they come, you'll never set...
# 58  country  [Verse 1]\nIt's not the long, flowing dress th...
# 59  country  [Verse 1]\nI gotta girl crush, hate to admit i...
# 60  country  [Refrain]\nSeen my share of broken halos\nFold...
#
# [61 rows x 4 columns]

# %%
# https://genius.com/api/songs/chart?page=1&per_page=10&tag_id=413&time_period=month
url1 = 'https://genius.com/api/songs/chart?page='
url2 = '&per_page=10&tag_id=413&time_period=month'
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36',
}

df_country2 = pd.DataFrame(columns= ['Song_Name', 'Artist', 'Genre', 'Lyrics'])

for x in range(1,15):
    json_country2 = requests.get(url1+ str(x) + url2, headers = headers).content
    
    
    con=json.loads(json_country2)

#     for t in range(0,9):
    lyrics_List= con["response"]["chart_items"]
    
    for item in lyrics_List:
        
        url= item['item']['url']   
        html = requests.get(url, headers = headers).content
        soup = BeautifulSoup(html,'html.parser')
        

        lyrics_list_soup = soup.find('div', attrs={'class': 'lyrics'})
        
        if(lyrics_list_soup.p is not None):
            lyrics1_list_soup = lyrics_list_soup.find('p').getText()
            if(lyrics1_list_soup == ""):
                lyrics1_list_soup = "no lyrics"
        else:
            lyrics1_list_soup = "no lyrics"

        Song_Name = soup.find('h1', attrs = {'class' : 'header_with_cover_art-primary_info-title'}).getText()
        artist_list_soup = soup.find('h2')
        Artist = artist_list_soup.find('a', attrs = {'class' : 'header_with_cover_art-primary_info-primary_artist'}).getText()
        Genre = "country"
        Lyrics = lyrics1_list_soup

        lyrics_data = [Song_Name, Artist, Genre, Lyrics]
#         print(lyrics_data)
    

        df_country2.loc[len(df_country2)] = [Song_Name, Artist, Genre, Lyrics]
df_country2
# Out:
#                                      Song_Name                    Artist  \
# 0                               Lovesick Blues             Hank Williams
# 1                                   Cry Pretty          Carrie Underwood
# 2                   Can't Help Falling In Love             Elvis Presley
# 3                                         Babe                 Sugarland
# 4                                Say Something         Justin Timberlake
# 5                          You Are My Sunshine               Johnny Cash
# 6                                  Meant to Be                Bebe Rexha
# 7                                       Jolene              Dolly Parton
# 8                                 Take It Easy                    Eagles
# 9              In Hell I'll Be in Good Company            The Dead South
# 10                                        Hurt               Johnny Cash
# 11                                        Stay               Post Malone
# 12                                     Up Down             Morgan Wallen
# 13                                       Mercy               Brett Young
# 14                             Whiskey Lullaby              Brad Paisley
# 15                 Take Me Home, Country Roads               John Denver
# 16                                Ring of Fire               Johnny Cash
# 17                                  Love Story              Taylor Swift
# 18                                   September              Taylor Swift
# 19                                   The Climb               Miley Cyrus
# 20                                    What Ifs                Kane Brown
# 21                               Queen's Don't                   RaeLynn
# 22                    Oh My Darling Clementine               Traditional
# 23                        Most People Are Good                Luke Bryan
# 24                        The End of the World             Skeeter Davis
# 25                           Tennessee Whiskey           Chris Stapleton
# 26                                   Get Along             Kenny Chesney
# 27                                         Hey                    Pixies
# 28                          You Belong With Me              Taylor Swift
# 29              The Devil Went Down to Georgia  The Charlie Daniels Band
