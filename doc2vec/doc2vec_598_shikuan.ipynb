# %%
import pandas as pd
import numpy as np
import csv
from nltk.stem import WordNetLemmatizer
from gensim.models.doc2vec import TaggedDocument
# Out:
# C:\LearnPython\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
df_general = pd.read_csv('lyrics_dfclean_598.csv')
del (df_general['Unnamed: 0'])
df_general
# Out:
#                                      Song_Name  \
# 0                         No Tears Left to Cry
# 1                                      FRIENDS
# 2                             A Million Dreams
# 3                                   The Middle
# 4                            Rewrite the Stars
# 5                                    âlovely
# 6                                   Be Careful
# 7                             Te BotÃ© (Remix)
# 8                                     One Kiss
# 9                                         SAD!
# 10                                         OTW
# 11                                 Hasta Luego
# 12                                 Take a Byte
# 13                        Crazy, Classic, Life
# 14                                        Ring
# 15                                  Youngblood
# 16                                Barbie Tingz
# 17                             Thru Your Phone
# 18                                    Somebody
# 19                              1-800-273-8255
# 20                                   Bom Diggy
# 21                                       Bukti
# 22                                     Perfect
# 23                             I Got the Juice
# 24            Raat Kamaal Hai 320Kbps MP3 Song
# 25                                        Mine
# 26                                   X (EQUIS)
# 27                             Finesse (Remix)
# 28                                        Baby
# 29                           The Greatest Show
# ..                                         ...
# 568                                   Criminal
# 569                    In Case You Didn't Know
# 570                                     Mother
# 571                       Stop Me from Falling
# 572                       Love Is a Wild Thing
# 573                               Broken Halos
# 574                            One Number Away
# 575                                  Last Kiss
# 576                          Ask Me How I Know
# 577                                Holy Ground
# 578                                    Picture
# 579                                  Dear John
# 580                                        Red
# 581                           Back To December
# 582                                The Gambler
# 583                                Heart Break
# 584                               Wonder Woman
# 585                  Something You Get Through
# 586  Chootay Maatay Mp3 Song Download Djpunjab
# 587                           Drinkin' Problem
# 588                     Teardrops On My Guitar
# 589                         Smokin' and Cryin'
# 590                          Streets of London
# 591           My My, Hey Hey (Out of the Blue)
# 592                              Rocky Raccoon
# 593                                Wagon Wheel
# 594                               Velvet Elvis
# 595                            All Summer Long
# 596                                  Fireworks
# 597                                       Toes
#
#                                       Artist    Genre  \
# 0                              Ariana Grande      Pop
# 1                    Marshmello & Anne-Marie      Pop
# 2                                Ziv Zaifman      Pop
# 3                                       Zedd      Pop
# 4                                  Zac Efron      Pop
# 5                     Billie Eilish & Khalid      Pop
# 6                                    Cardi B      Pop
# 7    Nio GarcÃ­a, Casper MÃ¡gico & Bad Bunny      Pop
# 8                   Calvin Harris & Dua Lipa      Pop
# 9                               XXXTENTACION      Pop
# 10             Khalid, 6LACK & Ty Dolla $ign      Pop
# 11                       HRVY & Malu Trevejo      Pop
# 12                            Janelle MonÃ¡e      Pop
# 13                            Janelle MonÃ¡e      Pop
# 14                                   Cardi B      Pop
# 15                       5 Seconds of Summer      Pop
# 16                               Nicki Minaj      Pop
# 17                                   Cardi B      Pop
# 18                          The Chainsmokers      Pop
# 19                                     Logic      Pop
# 20                Zack Knight & Jasmin Walia      Pop
# 21                                   Virgoun      Pop
# 22                                Ed Sheeran      Pop
# 23                            Janelle MonÃ¡e      Pop
# 24                Guru Randhawa, Tulsi Kumar      Pop
# 576  stubborn come never settle always one stick ar...     577
# 577  reminiscing day coffee alone lord took away ba...     578
# 578  living life slow hell different girl every nig...     579
# 579  long nights days revolved around counting foot...     580
# 580  loving like driving new maserati dead end stre...     581
# 581  glad made time see life tell family seen good ...     582
# 582  warm summer evenin train bound nowhere met gam...     583
# 583  paint lips red turn head need nobody help zipp...     584
# 584  like going like rarely never ever see eye eye ...     585
# 585  lose one love think world ended think world wa...     586
# 586  visit chootay maatay guri mp3 song download li...     587
# 587  one night one one one round first one last one...     588
# 588  drew looks fake smile see want needing everyth...     589
# 589  sittin waitin tables sittin waitin show name s...     590
# 590  seen old man closed market kicking paper worn ...     591
# 591  hey hey rock roll stay better burn fade away h...     592
# 592  somewhere black mining hills dakota lived youn...     593
# 593  headed south land pines thumbin way north caro...     594
# 594  ever wanted something classic kind love song g...     595
# 595  1989 thoughts short hair long caught somewhere...     596
# 596  could sworn saw fireworks house last night lig...     597
# 597  got toes water ass sand worry world cold beer ...     598
#
# [598 rows x 5 columns]

# %%
wnl = WordNetLemmatizer()

class Sentences(object):
    
    def __init__(self, filename, column):
        self.filename = filename
        self.column = column
        
    @staticmethod
    def get_tokens(text):
        """Helper function for tokenizing data"""
        return [wnl.lemmatize(r.lower()) for r in text.split()]
 
    def __iter__(self):
        reader = csv.DictReader(open(self.filename, 'r' ))
        for row in reader:
            words = self.get_tokens(row[self.column])
            tags = ['%s|%s' % (row['Artist'], row['SongID'])]
            yield TaggedDocument(words=words, tags=tags)

# %%
filename = 'lyrics_dfclean_598.csv'
sentences = Sentences(filename=filename, column='Lyrics')

# for song lookups
df_train = pd.read_csv(filename)

# %%
n_dim = 300

# %%
from gensim.models.doc2vec import Doc2Vec

model = Doc2Vec(
    alpha=0.025,
    min_alpha=0.025,
    workers=15, 
    min_count=2,
    window=10,
    size=300,
    iter=20,
    sample=0.001,
    negative=5
)
# Out:
# C:\LearnPython\lib\site-packages\gensim\models\doc2vec.py:362: UserWarning: The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.
#   warnings.warn("The parameter `iter` is deprecated, will be removed in 4.0.0, use `epochs` instead.")
# C:\LearnPython\lib\site-packages\gensim\models\doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
model.build_vocab(sentences)

# %%
model.save('lyrics598.doc2vec')

model = Doc2Vec.load('lyrics598.doc2vec')

# %%
model.wv.word_vec('look')
# Out:
# array([ 6.43691339e-04, -8.43589893e-04, -2.64992676e-04, -6.27334113e-04,
#        -8.44512775e-04,  1.19857886e-03, -7.49203435e-04, -9.30247945e-04,
#         8.11470207e-04,  7.08626816e-04,  5.78158826e-04,  4.07293846e-04,
#        -7.65120203e-04,  1.63657044e-03, -2.01943316e-04,  5.53486578e-04,
#         8.50060664e-04,  3.05975205e-04,  3.30239505e-04, -8.87740985e-04,
#         6.43991516e-04, -6.40007784e-04,  6.78881246e-04,  7.79793598e-04,
#        -1.62045099e-03, -1.39574485e-03, -1.12805853e-03, -1.60233211e-03,
#        -1.26680607e-04, -3.43428808e-04,  1.17881200e-03,  1.17479044e-03,
#        -1.59273541e-03,  1.06306886e-03, -1.16418011e-03, -4.40394768e-04,
#         8.24818970e-04, -4.84587596e-04,  9.97829949e-04, -9.72598849e-04,
#         1.61214755e-03,  1.41382311e-03,  1.07043935e-03, -1.21314297e-04,
#         8.10254656e-04, -4.96908091e-04,  9.56565607e-04,  7.18414158e-05,
#        -7.98057707e-04, -1.20404037e-03,  1.35077082e-03,  4.49289539e-04,
#        -1.04257499e-03, -1.20100763e-03, -1.15183077e-03, -4.71915155e-05,
#         1.05802447e-03, -6.90155866e-05, -1.17286958e-03, -4.56660491e-04,
#        -2.53831648e-04,  5.07056771e-04, -1.37980713e-03, -3.16044461e-04,
#        -8.55474675e-04,  1.07299979e-03, -7.64819735e-04, -3.31849355e-04,
#         5.69920114e-04,  9.02120955e-04, -1.06916286e-03,  1.36848900e-03,
#         3.29449773e-04,  8.93680786e-04,  1.28276006e-03, -7.93719839e-04,
#        -7.07760861e-04,  1.51498569e-03, -3.38846497e-04, -1.21371566e-04,
#         2.97801191e-04,  4.37823648e-04,  8.21135647e-04, -5.70208416e-04,
#         1.55489647e-03, -5.36835694e-04,  1.53191132e-03,  1.31387054e-03,
#         1.47463928e-03,  1.42535660e-03, -8.56159604e-05, -8.32594815e-04,
#         1.25296006e-03,  1.26278086e-03, -7.10167340e-04,  1.03523384e-03,
#         1.26841172e-04,  1.41700177e-04, -7.26460712e-05, -5.35593368e-04,
#         7.12367182e-04,  9.13938420e-05,  1.25881995e-03, -1.45939214e-03,
#        -3.40960512e-04,  7.24501791e-04,  6.68071327e-04, -8.67840310e-04,
#         5.34925028e-04, -6.79404940e-04,  7.72546104e-04, -1.27047242e-03,
#         1.63815834e-03, -9.37965408e-04,  1.52919674e-03, -3.78582132e-04,
#         4.36412985e-04,  6.24350738e-04,  4.79437702e-04, -1.45337754e-03,
#        -1.56769797e-03,  5.08766789e-05, -5.91718708e-04,  3.28959322e-05,
#        -1.04493380e-03,  1.64465292e-03, -5.02384617e-04, -1.04449864e-03,
#        -5.16687986e-04,  1.30894687e-03,  1.08332059e-03,  1.43944344e-03,
#        -1.61916320e-03,  6.45295891e-04, -1.74254528e-04,  9.38277401e-04,
#        -6.17692480e-04, -1.19284482e-03,  5.61325403e-04,  6.38205383e-04,
#        -4.07179701e-04, -1.73400287e-04, -9.55077121e-04,  1.37439999e-03,
#        -1.44294463e-03, -1.00487808e-03, -2.18009271e-04,  1.66104687e-03,
#         1.03090878e-03,  2.94923724e-04,  9.51044785e-04, -1.38726924e-03,
#         7.92177627e-04,  5.83438319e-04, -2.82511814e-04, -1.64211786e-03,
#         4.09342902e-05, -8.06312193e-04, -9.83214937e-04, -3.66429274e-04],
#       dtype=float32)

# %%
def print_songs(results):
    lookup = lambda x: df_train[
        df_train.SongID==int(x)
    ].Song_Name.values[0]
    return [
        [
            i[0].split('|')[0], 
            lookup(i[0].split('|')[1]), 
            i[1]
        ] for i in results
    ]

# %%
print_songs(
    model.docvecs.most_similar([model['country']], topn=10)
)
# Out:
# [['Dolly Parton', 'Jolene', 0.16160523891448975],
#  ['Virgoun', 'Bukti', 0.15511712431907654],
#  ['Larray', 'First Place (The Race - Remix)', 0.14716432988643646],
#  ['Hugh Jackman', 'The Other Side', 0.13595302402973175],
#  ['Demi Lovato', 'Sorry Not Sorry', 0.13429497182369232],
#  ['Taylor Swift', 'Enchanted', 0.13356564939022064],
#  ['Johnny Cash', 'You Are My Sunshine', 0.1256883293390274],
#  ['5 Seconds of Summer', 'Youngblood', 0.11990809440612793],
#  ['Cakra Khan', 'Kekasih Bayangan', 0.11939827352762222],
#  ['Lady Gaga', 'Million Reasons', 0.11657141149044037]]

# %%
model['country'].size
# Out:
# 300

# %%
from gensim.models.doc2vec import TaggedDocument
from sklearn.cross_validation import train_test_split
# Out:
# C:\LearnPython\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X = df_general.loc[:,'Lyrics']
y = df_general.Genre

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import normalize

# %%
def getVecs_doc2vec(model, corpus, size):
    vec = np.zeros(size).reshape((1,size))
    count = 0.
    for word in corpus:
        try:
            vec += model[word].reshape((1,size))
            count += 1.
        except KeyError:
            continue
    if count != 0 :
        vec /= count
    return vec

# %%
train_vecs_dm = np.concatenate([getVecs_doc2vec(model, z,n_dim) for z in X_train])
train_vecs_dm = normalize(train_vecs_dm)

# %%
test_vecs_dm = np.concatenate([getVecs_doc2vec(model, z,n_dim) for z in X_test])
test_vecs_dm = normalize(test_vecs_dm)

# %%
from sklearn.linear_model import SGDClassifier

lr = SGDClassifier(loss = 'log', penalty='l1')

# %%
lr = SGDClassifier(loss = 'log', penalty='l1')
lr.fit(train_vecs_dm, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dm,y_test))
# Out:
# test accuraccy: 0.51
# C:\LearnPython\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs_dm, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dm,y_test))
# Out:
# test accuraccy: 0.52
# C:\LearnPython\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
from sklearn import svm
clf = svm.SVC(C=0.8, kernel='linear',  decision_function_shape='ovo')
clf.fit(train_vecs_dm,y_train)
print(clf.score(train_vecs_dm,y_train))
print(clf.score(test_vecs_dm,y_test))
# Out:
# 0.5669856459330144
# 0.5166666666666667

# %%
clf = svm.SVC(C=0.7, kernel='rbf', gamma=0.8, decision_function_shape='ovr')
clf.fit(train_vecs_dm,y_train)
print(clf.score(train_vecs_dm,y_train))
print(clf.score(test_vecs_dm,y_test))
# Out:
# 0.5933014354066986
# 0.55

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
param_test1_dm = {'n_estimators':range(10,251,10)}
gsearch1_dm = GridSearchCV(estimator = RandomForestClassifier(n_jobs= 4), param_grid = param_test1_dm, scoring='accuracy',cv=10)
gsearch1_dm.fit(train_vecs_dm,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=4,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': range(10, 251, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
print(gsearch1_dm.best_params_)
print(gsearch1_dm.best_score_)
# Out:
# {'n_estimators': 30}
# 0.7966507177033493

# %%
clf_dm = RandomForestClassifier(n_estimators=180, n_jobs=4,)
clf_dm.fit(train_vecs_dm,y_train)

clf_dm.score(test_vecs_dm,y_test)
# Out:
# 0.8222222222222222
