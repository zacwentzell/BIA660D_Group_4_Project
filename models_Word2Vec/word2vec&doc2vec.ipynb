# %%
import pandas as pd
import numpy as np
import re

# %%
pop_lyrics = pd.read_csv('lyrics_pop_300.csv')
del (pop_lyrics['Unnamed: 0'])
pop_lyrics
# Out:
#                              Song_Name                                 Artist  \
# 0                 No Tears Left to Cry                          Ariana Grande
# 1                              FRIENDS                Marshmello & Anne-Marie
# 2                     A Million Dreams                            Ziv Zaifman
# 3                           The Middle                                   Zedd
# 4                    Rewrite the Stars                              Zac Efron
# 5                              ​lovely                 Billie Eilish & Khalid
# 6                           Be Careful                                Cardi B
# 7                      Te Boté (Remix)  Nio García, Casper Mágico & Bad Bunny
# 8                             One Kiss               Calvin Harris & Dua Lipa
# 9                                 SAD!                           XXXTENTACION
# 10                                 OTW          Khalid, 6LACK & Ty Dolla $ign
# ...

# %%
x = pop_lyrics.loc[:,'Lyrics']
x[0]
# Out:
# "[Intro]\r\nRight now, I'm in a state of mind\r\nI wanna be in, like, all the time\r\nAin't got no tears left to cry\r\nSo I'm pickin' it up, pickin' it up\r\nI'm lovin', I'm livin', I'm pickin' it up\r\nI'm pickin' it up, pickin' it up\r\nI'm lovin', I'm livin', I'm pickin' it up (oh, yeah)\r\n\r\n[Refrain]\r\nI'm pickin' it up (yeah), pickin' it up (yeah)\r\nLovin', I'm livin', so we turnin' it up\r\nYeah, we turnin' it up\r\n\r\n[Verse 1]\r\nAin't got no tears in my body\r\nI ran out, but boy, I like it, I like it, I like it\r\nDon't matter how, what, when, who tries it\r\nWe're out here vibin', we vibin', we vibin'\r\n\r\n[Pre-Chorus]\r\nComin' out\r\nEven when it's rainin' down (can't stop now)\r\nCan't stop so shut your mouth (shut your mouth)\r\nAnd if you don't know then now you know it, babe\r\nKnow it, babe, yeah\r\n\r\n[Chorus]\r\nRight now, I'm in a state of mind\r\nI wanna be in, like, all the time\r\nAin't got no tears left to cry\r\nSo I'm pickin' it up, pickin' it up 
# ...

# %%
x[0] = re.sub(r'\[.*?\]','',x[0])

# %%
x[0]
# Out:
# "\r\nRight now, I'm in a state of mind\r\nI wanna be in, like, all the time\r\nAin't got no tears left to cry\r\nSo I'm pickin' it up, pickin' it up\r\nI'm lovin', I'm livin', I'm pickin' it up\r\nI'm pickin' it up, pickin' it up\r\nI'm lovin', I'm livin', I'm pickin' it up (oh, yeah)\r\n\r\n\r\nI'm pickin' it up (yeah), pickin' it up (yeah)\r\nLovin', I'm livin', so we turnin' it up\r\nYeah, we turnin' it up\r\n\r\n\r\nAin't got no tears in my body\r\nI ran out, but boy, I like it, I like it, I like it\r\nDon't matter how, what, when, who tries it\r\nWe're out here vibin', we vibin', we vibin'\r\n\r\n\r\nComin' out\r\nEven when it's rainin' down (can't stop now)\r\nCan't stop so shut your mouth (shut your mouth)\r\nAnd if you don't know then now you know it, babe\r\nKnow it, babe, yeah\r\n\r\n\r\nRight now, I'm in a state of mind\r\nI wanna be in, like, all the time\r\nAin't got no tears left to cry\r\nSo I'm pickin' it up, pickin' it up (oh yeah)\r\nI'm lovin', I'm livin', I'm pick
# ...

# %%
# rap_lyrics["genre"] = "rap"
# rap_lyrics

# %%
from sklearn.pipeline import Pipeline

from sklearn.feature_extraction import stop_words

# %%
def cleanText(corpus):
    preprocessed_sentences = []
    word_bag = []
    stop_words = common_terms
    pos_to_keep=('NOUN', 'PROPN', 'ADJ', 'VERB')
    for doc in nlp.pipe(corpus, n_threads=8):
        keep_tokens_string = ' '.join([t.lemma_ for t in doc if t.pos_ in pos_to_keep and t.lemma_ not in stop_words])
        preprocessed_sentences.append(keep_tokens_string)
    preprocessed_sentences = [z.lower().replace('\n',' ').split() for z in preprocessed_sentences]
    for sentence in preprocessed_sentences:
        for word in sentence:
            word_bag.append(word)
    return word_bag

# %%
common_terms = list(stop_words.ENGLISH_STOP_WORDS) + ["m", "re", "ll", "s", "ve", "d", 'ca', 'is','-PRON-','t','g','don','ain','b','r']

# %%
sorted(common_terms)
# Out:
# ['-PRON-',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amoungst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'b',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'bill',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'cant',
#  'co',
#  'con',
#  'could',
#  'couldnt',
#  'cry',
#  'd',
#  'de',
#  'describe',
#  'detail',
#  'do',
#  'don',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'eleven',
# ...

# %%
common_terms.remove('now')

# %%
def StopStem(df):
    stop = common_terms
    
    df['Lyrics'] = df['Lyrics'].apply(lambda x: re.sub(r'\[.*?\]',' ',x))
    
    df['Lyrics'] = df['Lyrics'].apply(lambda x: re.sub('[’‘!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]+',' ',x))
#     df["Lyrics"] = re.sub(r'[.*?]', '', df['Lyrics'].string)
    df["Lyrics"] = df['Lyrics'].str.lower().replace('[^\w\s]',' ')
    df["Lyrics"] = df['Lyrics'].str.replace('\r\n',' ')
    df['Lyrics'] = df['Lyrics'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
    return df

# %%
pop_lyrics = StopStem(pop_lyrics)

# %%
pop_lyrics
# Out:
#                              Song_Name                                 Artist  \
# 0                 No Tears Left to Cry                          Ariana Grande
# 1                              FRIENDS                Marshmello & Anne-Marie
# 2                     A Million Dreams                            Ziv Zaifman
# 3                           The Middle                                   Zedd
# 4                    Rewrite the Stars                              Zac Efron
# 5                              ​lovely                 Billie Eilish & Khalid
# 6                           Be Careful                                Cardi B
# 7                      Te Boté (Remix)  Nio García, Casper Mágico & Bad Bunny
# 8                             One Kiss               Calvin Harris & Dua Lipa
# 9                                 SAD!                           XXXTENTACION
# 10                                 OTW          Khalid, 6LACK & Ty Dolla $ign
# ...

# %%
x = pop_lyrics.loc[:,'Lyrics']

# %%
x[0]
# Out:
# 'right now state mind wanna like time got tears left pickin pickin lovin livin pickin pickin pickin lovin livin pickin oh yeah pickin yeah pickin yeah lovin livin turnin yeah turnin got tears body ran boy like like like matter tries vibin vibin vibin comin rainin stop now stop shut mouth shut mouth know now know babe know babe yeah right now state mind wanna like time got tears left pickin pickin oh yeah lovin livin pickin oh just want come mentality got tears left pickin pickin oh yeah lovin livin pickin pickin yeah pickin yeah lovin livin turnin turnin yeah turnin point colors em boy like em like em like em way fly partake hate vibin vibin vibin comin rainin stop now stop shut mouth shut mouth know now know babe know babe yeah right now state mind wanna like time got tears left pickin pickin oh yeah lovin livin pickin oh just want come mentality got tears left pickin pickin oh yeah lovin livin pickin comin rainin stop now hmm oh shut mouth got tears left oh yeah oh yeah oh just wan
# ...

# %%
country_lyrics = pd.read_csv('lyrics_country_299.csv')
del (country_lyrics['Unnamed: 0'])
country_lyrics
# Out:
#                                      Song_Name  \
# 0                               Lovesick Blues
# 1    Chootay Maatay Mp3 Song Download Djpunjab
# 2                                         Babe
# 3                          You Are My Sunshine
# 4                                Say Something
# 5                                   Cry Pretty
# 6                   Can't Help Falling In Love
# 7                                  Meant to Be
# 8                                       Jolene
# 9                                         Stay
# 10                                       Mercy
# 11                   Something You Get Through
# 12             In Hell I'll Be in Good Company
# 13                                    What Ifs
# 14                                 Самая вышка
# 15                                   Get Along
# 16                 Take Me Home, Country Roads
# 17                                        Hurt
# 18                                Take It Easy
# ...

# %%
country_lyrics = StopStem(country_lyrics)

# %%
country_lyrics['Lyrics'][5]
# Out:
# 'sorry just girl usually kind heart world pretty good keeping hold composure worse better apologize like emotions best falling apart human gets hide fight truth pretty lie say okay pretty smile just walk away pretty fake way pretty oh dress lace rhinestones matter crowd home yeah looking mirror picture pain let flow like river pretty lie say okay pretty smile just walk away pretty fake way pretty turn flood dam breaks mascara going waste things ugly just gotta face pretty oh ooh yeah turn flood dam breaks mascara going waste things ugly just gotta face pretty yeah yeah yeah yeah yeah yeah yeah yeah yeah woo pretty baby oh yeah woo woo pretty yeah'

# %%
pop_lyrics.drop([299],inplace = True)

# %%
pop_lyrics
# Out:
#                              Song_Name                                 Artist  \
# 0                 No Tears Left to Cry                          Ariana Grande
# 1                              FRIENDS                Marshmello & Anne-Marie
# 2                     A Million Dreams                            Ziv Zaifman
# 3                           The Middle                                   Zedd
# 4                    Rewrite the Stars                              Zac Efron
# 5                              ​lovely                 Billie Eilish & Khalid
# 6                           Be Careful                                Cardi B
# 7                      Te Boté (Remix)  Nio García, Casper Mágico & Bad Bunny
# 8                             One Kiss               Calvin Harris & Dua Lipa
# 9                                 SAD!                           XXXTENTACION
# 10                                 OTW          Khalid, 6LACK & Ty Dolla $ign
# ...

# %%
df_general = pop_lyrics.append(country_lyrics)

# %%
df_general
# Out:
#                                      Song_Name  \
# 0                         No Tears Left to Cry
# 1                                      FRIENDS
# 2                             A Million Dreams
# 3                                   The Middle
# 4                            Rewrite the Stars
# 5                                      ​lovely
# 6                                   Be Careful
# 7                              Te Boté (Remix)
# 8                                     One Kiss
# 9                                         SAD!
# 10                                         OTW
# 11                                 Hasta Luego
# 12                                 Take a Byte
# 13                        Crazy, Classic, Life
# 14                                        Ring
# 15                                  Youngblood
# 16                                Barbie Tingz
# 17                             Thru Your Phone
# 18                                    Somebody
# ...

# %%
df_general.Lyrics = df_general.Artist.str.cat(df_general.Lyrics,sep=' ')
df_general
# Out:
#                                      Song_Name  \
# 0                         No Tears Left to Cry
# 1                                      FRIENDS
# 2                             A Million Dreams
# 3                                   The Middle
# 4                            Rewrite the Stars
# 5                                      ​lovely
# 6                                   Be Careful
# 7                              Te Boté (Remix)
# 8                                     One Kiss
# 9                                         SAD!
# 10                                         OTW
# 11                                 Hasta Luego
# 12                                 Take a Byte
# 13                        Crazy, Classic, Life
# 14                                        Ring
# 15                                  Youngblood
# 16                                Barbie Tingz
# 17                             Thru Your Phone
# 18                                    Somebody
# ...

# %%
import spacy
nlp = spacy.load('en')
X = pop_lyrics.loc[:,'Lyrics']
pop_word_bag = cleanText(X)

# %%
X = country_lyrics.loc[:,'Lyrics']
country_word_bag = cleanText(X)
country_word_bag
# Out:
# ['feel',
#  'blue',
#  'lord',
#  'baby',
#  'say',
#  'goodbye',
#  'lord',
#  'know',
#  'sit',
#  'sigh',
#  'lord',
#  'long',
#  'day',
#  'say',
#  'goodbye',
#  'lord',
#  'think',
#  'love',
#  'lord',
#  'love',
#  'hear',
#  'sweet',
#  'daddy',
#  'beautiful',
#  'dream',
#  'hate',
#  'think',
#  'lose',
#  'heart',
#  'grow',
#  'used',
#  'sugar',
#  'daddy',
#  'lonesome',
#  'lovesick',
#  'blue',
#  'love',
#  'love',
#  'beautiful',
#  'gal',
#  'matter',
#  'love',
#  'love',
#  'beautiful',
#  'gal',
#  'care',
#  'lord',
#  'try',
#  'try',
#  'satisfied',
#  'wouldn',
#  'stay',
#  'leave',
#  'say',
#  'feel',
#  'blue',
#  'lord',
#  'baby',
#  'say',
#  'goodbye',
#  'lord',
#  'know',
#  'sit',
#  'sigh',
#  'lord',
#  'long',
#  'day',
#  'say',
#  'goodbye',
#  'lord',
#  'think',
#  'love',
#  'lord',
#  'love',
#  'hear',
#  'sweet',
#  'daddy',
#  'beautiful',
#  'dream',
#  'hate',
#  'think',
#  'lose',
#  'heart',
#  'grow',
#  'used',
#  'sugar',
# ...

# %%
unique_words_country = list(set(country_word_bag))

freq_country = []
for word in unique_words_country:
        freq_country.append((word, country_word_bag.count(word)))

    #sort
freq_country.sort(key = lambda x : x[1], reverse=True)

# %%
unique_words_pop = list(set(pop_word_bag))

freq_pop = []
for word in unique_words_pop:
        freq_pop.append((word, pop_word_bag.count(word)))

    #sort
freq_pop.sort(key = lambda x : x[1], reverse=True)

# %%
common_word = []

for i in freq_pop:
    for j in freq_country:
        if i[0]==j[0]:
            common_word.append(i[0])
common_word
# Out:
# ['know',
#  'love',
#  'let',
#  'come',
#  'say',
#  'baby',
#  'feel',
#  'want',
#  'time',
#  'tell',
#  'night',
#  'wanna',
#  'look',
#  'make',
#  'good',
#  'need',
#  'way',
#  'day',
#  'think',
#  'girl',
#  'heart',
#  'man',
#  'mind',
#  'life',
#  'run',
#  'tonight',
#  'eye',
#  'hold',
#  'thing',
#  'win',
#  'break',
#  'leave',
#  'wait',
#  'babe',
#  'work',
#  'bitch',
#  'lose',
#  'dream',
#  'low',
#  'friend',
#  'try',
#  'world',
#  'crazy',
#  'fuck',
#  'stop',
#  'hit',
#  'face',
#  'star',
#  'little',
#  'body',
#  'lie',
#  'head',
#  'new',
#  'ring',
#  'tryna',
#  'fall',
#  'goodbye',
#  'somebody',
#  'light',
#  'old',
#  'die',
#  'shit',
#  'hand',
#  'song',
#  'care',
#  'talk',
#  'phone',
#  'fly',
#  'walk',
#  'live',
#  'mean',
#  'turn',
#  'meet',
#  'bad',
#  'close',
#  'beautiful',
#  'boy',
#  'pain',
#  'hear',
#  'e',
#  'pull',
#  'wrong',
#  'stay',
#  'hurt',
#  'wild',
#  'great',
#  'home',
#  'hope',
#  'play',
# ...

# %%
def clean(corpus):
    preprocessed_sentences = []
    stop_words = common_terms
    pos_to_keep=('NOUN', 'PROPN', 'ADJ', 'VERB')
    for doc in nlp.pipe(corpus, n_threads=8):
        keep_tokens_string = ' '.join([t.lemma_ for t in doc if t.pos_ in pos_to_keep and t.lemma_ not in stop_words and t.lemma_ not in common_word])
#         doc = nlp(lyrics)
#         lyrics = ' '.join([t.lemma_ for t in doc if t.pos_ in pos_to_keep and t.lemma_ not in stop_words])
        preprocessed_sentences.append(keep_tokens_string)
    preprocessed_sentences = [z.lower().replace('\n',' ').split() for z in preprocessed_sentences]
    return preprocessed_sentences

# %%
from sklearn.cross_validation import train_test_split

# %%
X = df_general.loc[:,'Lyrics']
y = df_general.Genre

# %%
import spacy

from gensim.models.phrases import Phrases, Phraser
from spacy.pipeline import Pipe

nlp = spacy.load('en')

# %%
X = clean(X)

# %%
sorted(common_terms)
# Out:
# ['-PRON-',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amoungst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'b',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'bill',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'cant',
#  'co',
#  'con',
#  'could',
#  'couldnt',
#  'cry',
#  'd',
#  'de',
#  'describe',
#  'detail',
#  'do',
#  'don',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'eleven',
# ...

# %%
X
# Out:
# [['ariana',
#   'grande',
#   'vibin',
#   'vibin',
#   'vibin',
#   'mentality',
#   'partake',
#   'vibin',
#   'vibin',
#   'vibin',
#   'mentality',
#   'mentality'],
#  ['marshmello',
#   'anne',
#   'marie',
#   'polite',
#   'obvious',
#   'obvious',
#   'polite',
#   'obvious',
#   'obvious',
#   'polite',
#   'obvious',
#   'obvious',
#   'obvious',
#   'obvious'],
#  ['ziv', 'zaifman', 'design', 'special', 'compile', 'runaway', 'design'],
#  ['zedd',
#   'cabinet',
#   'bare',
#   'unaware',
#   'aggressive',
#   'intention',
#   'ohh',
#   'tap',
#   'aggressive',
#   'intention',
#   'admission',
#   'objection'],
#  ['zac',
#   'efron',
#   'claim',
#   'destiny',
#   'rewrite',
#   'rewrite',
#   'hopeless',
#   'rewrite',
#   'rewrite',
#   'rewrite',
#   'rewrite'],
#  ['billie', 'eilish', 'khalid'],
#  ['cardi',
#   'currys',
#   'steph',
#   'ayesha',
#   'tommy',
#   'keisha',
#   'tlc',
#   'lesson',
#   'likin',
#   'returnin',
#   'message',
#   'stutter',
# ...

# %%
len(X)
# Out:
# 598

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# [['zac',
#   'efron',
#   'claim',
#   'destiny',
#   'rewrite',
#   'rewrite',
#   'hopeless',
#   'rewrite',
#   'rewrite',
#   'rewrite',
#   'rewrite'],
#  ['hozier',
#   'humour',
#   'giggle',
#   'funeral',
#   'disapproval',
#   'worship',
#   'mouthpiece',
#   'bleak',
#   'poison',
#   'offer',
#   'absolute',
#   'worship',
#   'command',
#   'worship',
#   'shrine',
#   'sharpen',
#   'offer',
#   'deathless',
#   'worship',
#   'shrine',
#   'sharpen',
#   'offer',
#   'deathless',
#   'pagan',
#   'sunlight',
#   'demand',
#   'sacrifice',
#   'drain',
#   'meaty',
#   'stable',
#   'starve',
#   'faithful',
#   'tasty',
#   'hungry',
#   'worship',
#   'shrine',
#   'sharpen',
#   'offer',
#   'deathless',
#   'worship',
#   'shrine',
#   'sharpen',
#   'offer',
#   'deathless',
#   'master',
#   'ritual',
#   'gentle',
#   'soil',
#   'earthly',
#   'worship',
#   'shrine',
#   'sharpen',
#   'offer',
#   'deathless',
#   'worship',
#   'shrine',
#   'sharpen',
# ...

# %%
y_train.describe()
# Out:
# count         418
# unique          2
# top       country
# freq          215
# Name: Genre, dtype: object

# %%
y_train
# Out:
# 108        Pop
# 272        Pop
# 298    country
# 179    country
# 297    country
# 83     country
# 168    country
# 182    country
# 94     country
# 265        Pop
# 180    country
# 171    country
# 69         Pop
# 231        Pop
# 103    country
# 278        Pop
# 217    country
# 50     country
# 208    country
# 149        Pop
# 124        Pop
# 248    country
# 165    country
# 185        Pop
# 227        Pop
# 290        Pop
# 247        Pop
# 289        Pop
# 249        Pop
# 143    country
#         ...
# 58         Pop
# 175    country
# 261    country
# 252        Pop
# 21         Pop
# 14     country
# 160    country
# 160        Pop
# 276        Pop
# 191        Pop
# 86     country
# 114    country
# 192    country
# 44     country
# 9      country
# 130        Pop
# 99         Pop
# 73     country
# 87         Pop
# 159    country
# 31     country
# 214        Pop
# 167    country
# 121        Pop
# 20         Pop
# 71         Pop
# 106        Pop
# 270        Pop
# ...

# %%
len(X_test)
# Out:
# 180

# %%
y_test
# Out:
# 110        Pop
# 287        Pop
# 264    country
# 77         Pop
# 181        Pop
# 284        Pop
# 10         Pop
# 169    country
# 78         Pop
# 112    country
# 55         Pop
# 118        Pop
# 109        Pop
# 287    country
# 224    country
# 234        Pop
# 30         Pop
# 212        Pop
# 184        Pop
# 86         Pop
# 2          Pop
# 72     country
# 234    country
# 295    country
# 68     country
# 17     country
# 72         Pop
# 135        Pop
# 255    country
# 137    country
#         ...
# 292    country
# 267    country
# 45     country
# 32     country
# 249    country
# 244        Pop
# 22         Pop
# 140    country
# 116        Pop
# 89         Pop
# 65     country
# 211        Pop
# 18         Pop
# 286    country
# 20     country
# 144        Pop
# 3      country
# 274        Pop
# 240    country
# 207    country
# 250        Pop
# 286        Pop
# 227    country
# 100    country
# 167        Pop
# 54         Pop
# 291        Pop
# 46         Pop
# ...

# %%
from gensim.models.word2vec import Word2Vec

# %%
n_dim = 500 

imdb_w2v = Word2Vec(size = n_dim, sample = 0.00001)
imdb_w2v.build_vocab(X_train)

# imdb_w2v.train(X_train)

# %%
len(X_train)
# Out:
# 418

# %%
imdb_w2v.train(X_train,total_examples = len(X_train),epochs = imdb_w2v.epochs)
# Out:
# (1572, 49315)

# %%
def buildWordVector(text, size):
    vec = np.zeros(size).reshape((1,size))
    count = 0.
    for word in text:
        try:
            vec += imdb_w2v[word].reshape((1,size))
            count += 1.
        except KeyError:
            continue
    if count != 0 :
        vec /= count
    return vec

# %%
from sklearn.preprocessing import scale

train_vecs = np.concatenate([buildWordVector(z,n_dim) for z in X_train])
train_vecs = scale(train_vecs)
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
imdb_w2v.train(X_test, total_examples = len(X_test), epochs = imdb_w2v.epochs)
# Out:
# (487, 26000)

# %%
test_vecs = np.concatenate([buildWordVector(z,n_dim) for z in X_test])
test_vecs = scale(test_vecs)
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
from sklearn.linear_model import SGDClassifier

lr = SGDClassifier(loss = 'log', penalty='l1')
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
lr.fit(train_vecs, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='log', max_iter=5, n_iter=None,
#        n_jobs=1, penalty='l1', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
print('test accuraccy: %.2f'%lr.score(test_vecs,y_test))
# Out:
# test accuraccy: 0.83

# %%
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.81

# %%
# from sklearn.metrics import roc_curve, auc
# import matplotlib.pyplot as plt

# %%
from sklearn import svm

# %%
clf = svm.SVC(C=0.9, kernel='linear', gamma=20, decision_function_shape='ovo')

# %%
clf.fit(train_vecs,y_train)
# Out:
# SVC(C=0.9, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovo', degree=3, gamma=20, kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
clf.score(train_vecs,y_train)
# Out:
# 0.92822966507177029

# %%
clf.score(test_vecs,y_test)
# Out:
# 0.81666666666666665

# %%
clf = svm.SVC(C=0.7, kernel='rbf', gamma=90, decision_function_shape='ovr')
clf.fit(train_vecs,y_train)
# Out:
# SVC(C=0.7, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=90, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print(clf.score(train_vecs,y_train))
print(clf.score(test_vecs,y_test))
# Out:
# 0.928229665072
# 0.533333333333

# %%
# y_hat = clf.predict(train_vecs)
# show_accuracy(y_hat, y_train, 'train set')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import cross_validation, metrics
import matplotlib.pylab as plt

# %%
param_test1 = {'n_estimators':range(10,151,10)}
gsearch1 = GridSearchCV(estimator = RandomForestClassifier(n_jobs= 4), 
param_grid = param_test1, scoring='accuracy',cv=10)
gsearch1.fit(train_vecs,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=4,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': range(10, 151, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
print(gsearch1.best_params_)
print(gsearch1.best_score_)
# Out:
# {'n_estimators': 70}
# 0.83971291866

# %%
clf = RandomForestClassifier(n_estimators=130, n_jobs=4,)
clf.fit(train_vecs,y_train)


clf.score(test_vecs,y_test)
# Out:
# 0.80555555555555558

# %%
clf = RandomForestClassifier(n_estimators=30, n_jobs=4,)
clf.fit(train_vecs,y_train)


clf.score(test_vecs,y_test)
# Out:
# 0.78888888888888886

# %%
param_test4 = {'max_depth':range(1,5), 'min_samples_split':range(2,10),'min_samples_leaf':range(1,5)}
gsearch4 = GridSearchCV(estimator = RandomForestClassifier(n_estimators=130,max_depth=1,min_samples_split=2,min_samples_leaf=42), param_grid = param_test4, scoring='accuracy',cv=10)
gsearch4.fit(train_vecs,y_train)
print(gsearch4.best_params_)
print(gsearch4.best_score_)
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 6}
# 0.83971291866

# %%
param_test4 = {'max_depth':range(1,5), 'min_samples_split':range(2,10),'min_samples_leaf':range(1,5)}
gsearch4 = GridSearchCV(estimator = RandomForestClassifier(n_estimators=30,max_depth=1,min_samples_split=2,min_samples_leaf=42), param_grid = param_test4, scoring='accuracy',cv=10)
gsearch4.fit(train_vecs,y_train)
print(gsearch4.best_params_)
print(gsearch4.best_score_)
# Out:
# {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.83014354067

# %%
from sklearn.preprocessing import normalize

# %%
train_vecs = np.concatenate([buildWordVector(z,n_dim) for z in X_train])
train_vecs = normalize(train_vecs)

test_vecs = np.concatenate([buildWordVector(z,n_dim) for z in X_test])
test_vecs = normalize(test_vecs)
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
lr = SGDClassifier(loss = 'log', penalty='l1')
lr.fit(train_vecs, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs,y_test))
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.82
# test accuraccy: 0.85

# %%
clf = svm.SVC(C=0.9, kernel='linear', gamma=0.5, decision_function_shape='ovo')
clf.fit(train_vecs,y_train)
clf.score(train_vecs,y_train)
clf.score(test_vecs,y_test)
# Out:
# 0.82222222222222219

# %%
from gensim.models.doc2vec import Doc2Vec
import gensim

# %%
n_dim = 1200
model_dm = Doc2Vec(min_count = 10,size = n_dim, sample = 0.00001, negtive = 20) 
model_dbow = Doc2Vec(min_count = 10,  size = n_dim, sample = 0.0001, dm=0, negtive = 20)
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\gensim\models\doc2vec.py:366: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
# Out:
# 0.80555555555555558

# %%
# model_dm.build_vocab(X_train+X_test)
from gensim.models.doc2vec import TaggedDocument

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
def tagelizeLyrics(lyrics, label_type):
    labelized = []
    for i,v in enumerate(lyrics):
#         words = self.get_tokens(row[self.column])
#         tags = ['%s|%s' % (row['Artist'], row['SongID'])]
#         yield TaggedDocument(words=words, tags=tags)
        words = v
        tags = ['%s_%s'%(label_type, i)]
        labelized.append(TaggedDocument(words=words, tags=tags)) 
        
    return labelized

# %%
X_train_tagged = tagelizeLyrics(X_train,'TRAIN')

# %%
X_train_tagged
# Out:
# [TaggedDocument(words=['know', 'want', 'secret', 'try', 'hide', 'know', 'want', 'say', 'hand', 'tie', 'claim', 'card', 'fate', 'pull', 'mile', 'reach', 'heart', 'stop', 'decide', 'destiny', 'rewrite', 'star', 'say', 'mean', 'say', 'rewrite', 'star', 'world', 'tonight', 'think', 'easy', 'think', 'want', 'run', 'mountain', 'door', 'walk', 'know', 'wonder', 'able', 'wall', 'wake', 'hopeless', 'rewrite', 'star', 'say', 'mean', 'tell', 'rewrite', 'star', 'say', 'world', 'tonight', 'want', 'fly', 'want', 'fall', 'feel', 'impossible', 'impossible', 'impossible', 'say', 'possible', 'rewrite', 'star', 'say', 'mean', 'say', 'rewrite', 'star', 'change', 'world', 'know', 'want', 'secret', 'try', 'hide', 'bind', 'break', 'hand', 'tie'], tags=['TRAIN_0']),
# ...

# %%
X_test_tagged = tagelizeLyrics(X_test,'TEST')

# %%
X_vocab = tagelizeLyrics(X_train+X_test,'vacab')

# %%
model_dm.build_vocab(X_vocab)
model_dm.save('lyrics_dm.doc2vec')

model_dm = Doc2Vec.load('lyrics_dm.doc2vec')

# %%
model_dm.train(X_vocab,total_examples = len(list(X_vocab)), epochs = model_dm.epochs)

# %%
model_dm.wv.vocab
# Out:
# {'know': <gensim.models.keyedvectors.Vocab at 0x2ae1b900160>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x2ae1b900240>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x2ae1b9002b0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x2ae1b900320>,
#  'hide': <gensim.models.keyedvectors.Vocab at 0x2ae1b900390>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x2ae1b900400>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x2ae1b900470>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x2ae1b9004e0>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x2ae1b900550>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x2ae1b9005c0>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x2ae1b900630>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x2ae1b9006a0>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x2ae1b900710>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x2ae1b900780>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x2ae1b9007f0>,
# ...

# %%
model_dbow.build_vocab(X_vocab)
model_dbow.save('lyrics_dbow.doc2vec')

model_dbow = Doc2Vec.load('lyrics_dbow.doc2vec')

# %%
model_dbow.wv.vocab
# Out:
# {'know': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39208>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x2ae1ba392e8>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39358>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x2ae1ba393c8>,
#  'hide': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39438>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x2ae1ba394a8>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39518>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39588>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x2ae1ba395f8>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39668>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x2ae1ba396d8>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39748>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x2ae1ba397b8>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39828>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x2ae1ba39898>,
# ...

# %%
model_dbow.train(X_vocab,total_examples = len(list(X_vocab)), epochs = model_dm.epochs)

# %%
model_dm['star'].size
# Out:
# 1200

# %%
model_dm.wv.most_similar('look')
# Out:
# [('know', 0.317705899477005),
#  ('good', 0.3052326738834381),
#  ('way', 0.26924556493759155),
#  ('baby', 0.26380833983421326),
#  ('day', 0.2576862871646881),
#  ('love', 0.25580674409866333),
#  ('girl', 0.24002757668495178),
#  ('tell', 0.2399168312549591),
#  ('fall', 0.2324732393026352),
#  ('time', 0.2298167645931244)]

# %%
from sklearn.preprocessing import normalize

# %%
def getVecs_doc2vec(model, corpus, size):
    vec = np.zeros(size).reshape((1,size))
    count = 0.
    for word in corpus:
        try:
            vec += model[word].reshape((1,size))
            count += 1.
        except KeyError:
            continue
    if count != 0 :
        vec /= count
    return vec

   
#     vecs = [np.array(model.docvecs[z.tags[0]]).reshape((1, size)) for z in corpus]
#     return np.concatenate(vecs)

# %%
train_vecs_dm = np.concatenate([getVecs_doc2vec(model_dm, z,n_dim) for z in X_train])
train_vecs_dm = normalize(train_vecs_dm)

# %%
train_vecs_dbow = np.concatenate([getVecs_doc2vec(model_dbow, z,n_dim) for z in X_train])
train_vecs_dbow = normalize(train_vecs_dbow)

# %%
test_vecs_dm = np.concatenate([getVecs_doc2vec(model_dm, z,n_dim) for z in X_test])
test_vecs_dm = normalize(test_vecs_dm)

# %%
test_vecs_dbow = np.concatenate([getVecs_doc2vec(model_dbow, z,n_dim) for z in X_test])
test_vecs_dbow = normalize(test_vecs_dbow)

# %%
lr = SGDClassifier(loss = 'log', penalty='l1')
lr.fit(train_vecs_dm, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dm,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.72

# %%
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs_dm, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dm,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.73

# %%
lr = SGDClassifier(loss = 'log', penalty='l1')
lr.fit(train_vecs_dbow, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dbow,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.77

# %%
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs_dbow, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dbow,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.75

# %%
clf = svm.SVC(C=0.8, kernel='linear',  decision_function_shape='ovo')
clf.fit(train_vecs_dm,y_train)
print(clf.score(train_vecs_dm,y_train))
print(clf.score(test_vecs_dm,y_test))
# Out:
# 0.822966507177
# 0.616666666667

# %%
clf = svm.SVC(C=0.9, kernel='linear', decision_function_shape='ovo')
clf.fit(train_vecs_dbow,y_train)
print(clf.score(train_vecs_dbow,y_train))
print(clf.score(test_vecs_dbow,y_test))
# Out:
# 0.928229665072
# 0.705555555556

# %%
clf = svm.SVC(C=0.7, kernel='rbf', gamma=0.8, decision_function_shape='ovr')
clf.fit(train_vecs_dm,y_train)
print(clf.score(train_vecs_dm,y_train))
print(clf.score(test_vecs_dm,y_test))
# Out:
# 0.83971291866
# 0.638888888889

# %%
clf = svm.SVC(C=0.7, kernel='rbf', gamma=0.8, decision_function_shape='ovr')
clf.fit(train_vecs_dbow,y_train)
print(clf.score(train_vecs_dbow,y_train))
print(clf.score(test_vecs_dbow,y_test))
# Out:
# 0.959330143541
# 0.738888888889

# %%
param_test1_dm = {'n_estimators':range(10,251,10)}
gsearch1_dm = GridSearchCV(estimator = RandomForestClassifier(n_jobs= 4), param_grid = param_test1_dm, scoring='accuracy',cv=10)
gsearch1_dm.fit(train_vecs_dm,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=4,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': range(10, 251, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
print(gsearch1_dm.best_params_)
print(gsearch1_dm.best_score_)
# Out:
# {'n_estimators': 170}
# 0.796650717703

# %%
clf_dm = RandomForestClassifier(n_estimators=180, n_jobs=4,)
clf_dm.fit(train_vecs_dm,y_train)

clf_dm.score(test_vecs_dm,y_test)
# Out:
# 0.77777777777777779

# %%
param_test1_dbow = {'n_estimators':range(10,201,10)}
gsearch1_dbow = GridSearchCV(estimator = RandomForestClassifier(n_jobs= 4), param_grid = param_test1_dbow, scoring='accuracy',cv=10)
gsearch1_dbow.fit(train_vecs_dbow,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=4,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': range(10, 201, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=0)

# %%
print(gsearch1_dbow.best_params_)
print(gsearch1_dbow.best_score_)
# Out:
# {'n_estimators': 130}
# 0.796650717703

# %%
clf_dbow = RandomForestClassifier(n_estimators=180, n_jobs=4,)
clf_dbow.fit(train_vecs_dbow,y_train)

clf_dbow.score(test_vecs_dbow,y_test)
# Out:
# 0.78333333333333333

# %%
train_vecs_dm = np.concatenate([getVecs_doc2vec(model_dm, z,n_dim) for z in X_train])
train_vecs_dm = scale(train_vecs_dm)
train_vecs_dbow = np.concatenate([getVecs_doc2vec(model_dbow, z,n_dim) for z in X_train])
train_vecs_dbow = scale(train_vecs_dbow)
test_vecs_dm = np.concatenate([getVecs_doc2vec(model_dm, z,n_dim) for z in X_test])
test_vecs_dm = scale(test_vecs_dm)
test_vecs_dbow = np.concatenate([getVecs_doc2vec(model_dbow, z,n_dim) for z in X_test])
test_vecs_dbow = scale(test_vecs_dbow)

# %%
r = SGDClassifier(loss = 'log', penalty='l1')
lr.fit(train_vecs_dm, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dm,y_test))
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs_dm, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dm,y_test))
lr = SGDClassifier(loss = 'log', penalty='l1')
lr.fit(train_vecs_dbow, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dbow,y_test))
lr = SGDClassifier(loss = 'log', penalty='l2')
lr.fit(train_vecs_dbow, y_train)
print('test accuraccy: %.2f'%lr.score(test_vecs_dbow,y_test))
# Out:
# C:\ProgramData\Anaconda3\envs\scraping\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# test accuraccy: 0.73
# test accuraccy: 0.74
# test accuraccy: 0.72
# test accuraccy: 0.72

# %%
clf = svm.SVC(C=0.8, kernel='linear',  decision_function_shape='ovo')
clf.fit(train_vecs_dm,y_train)
print(clf.score(train_vecs_dm,y_train))
print(clf.score(test_vecs_dm,y_test))
clf = svm.SVC(C=0.9, kernel='linear', decision_function_shape='ovo')
clf.fit(train_vecs_dbow,y_train)
print(clf.score(train_vecs_dbow,y_train))
print(clf.score(test_vecs_dbow,y_test))
clf = svm.SVC(C=0.7, kernel='rbf', gamma=0.5, decision_function_shape='ovr')
clf.fit(train_vecs_dm,y_train)
print(clf.score(train_vecs_dm,y_train))
print(clf.score(test_vecs_dm,y_test))
clf = svm.SVC(C=0.7, kernel='rbf', gamma=0.5, decision_function_shape='ovr')
clf.fit(train_vecs_dbow,y_train)
print(clf.score(train_vecs_dbow,y_train))
print(clf.score(test_vecs_dbow,y_test))
# Out:
# 0.988038277512
# 0.777777777778
# 0.988038277512
# 0.777777777778
# 0.988038277512
# 0.466666666667
# 0.988038277512
# 0.466666666667

# %%
param_test1_dm = {'n_estimators':range(10,251,10)}
gsearch1_dm = GridSearchCV(estimator = RandomForestClassifier(n_jobs= 4), param_grid = param_test1_dm, scoring='accuracy',cv=10)
gsearch1_dm.fit(train_vecs_dm,y_train)
print(gsearch1_dm.best_params_)
print(gsearch1_dm.best_score_)
clf_dm = RandomForestClassifier(n_estimators=180, n_jobs=4,)
clf_dm.fit(train_vecs_dm,y_train)

clf_dm.score(test_vecs_dm,y_test)
# Out:
# {'n_estimators': 190}
# 0.796650717703
# 0.7944444444444444

# %%
clf_dm = RandomForestClassifier(n_estimators=190, n_jobs=4,)
clf_dm.fit(train_vecs_dm,y_train)

clf_dm.score(test_vecs_dm,y_test)
# Out:
# 0.82777777777777772

# %%
param_test1_dbow = {'n_estimators':range(10,201,10)}
gsearch1_dbow = GridSearchCV(estimator = RandomForestClassifier(n_jobs= 4), param_grid = param_test1_dbow, scoring='accuracy',cv=10)
gsearch1_dbow.fit(train_vecs_dbow,y_train)
print(gsearch1_dbow.best_params_)
print(gsearch1_dbow.best_score_)
clf_dbow = RandomForestClassifier(n_estimators=180, n_jobs=4,)
clf_dbow.fit(train_vecs_dbow,y_train)

clf_dbow.score(test_vecs_dbow,y_test)
# Out:
# {'n_estimators': 160}
# 0.808612440191
# 0.76111111111111107

# %%
clf_dbow = RandomForestClassifier(n_estimators=160, max_features=300, n_jobs=4,)
clf_dbow.fit(train_vecs_dbow,y_train)

clf_dbow.score(test_vecs_dbow,y_test)
# Out:
# 0.81111111111111112
